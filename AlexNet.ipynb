# %% [markdown]
# <a href="https://colab.research.google.com/github/anishjohnson/Face-Emotion-Recognition/blob/main/FER/Colab%20Notebook/Face_Emotion_Recognition_Anish_Johnson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Face Emotion Recognition**

# %% [markdown]
# # **Objective**
# Our objective is to solve the above mentioned challenge by applying deep learning algorithms to live video data inorder to recognize the facial emotions and categorize them accordingly.

# %% [markdown]
# # **Dataset used**
# We have utilized the [FER 2013](https://www.kaggle.com/datasets/msambare/fer2013) dataset provided on Kaggle.<br>
# The data consists of 48x48 pixel grayscale images of faces. The faces have been automatically registered so that the face is more or less centred and occupies about the same amount of space in each image.<br>
#
# The task is to categorize each face based on the emotion shown in the facial expression into one of seven categories (0=Angry, 1=Disgust, 2=Fear, 3=Happy, 4=Sad, 5=Surprise, 6=Neutral). The training set consists of 28,709 examples and the public test set consists of 3,589 examples.

# %%
# !nvidia-smi
# !nvcc -V
# Out:
# Thu Feb 16 11:58:30 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 528.33       Driver Version: 528.33       CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   45C    P8     4W /  80W |   4673MiB /  6144MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A     15404      C   ...ython\Python38\python.exe    N/A      |
# +-----------------------------------------------------------------------------+
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Fri_Jan__6_19:04:39_Pacific_Standard_Time_2023
# Cuda compilation tools, release 12.0, V12.0.140
# Build cuda_12.0.r12.0/compiler.32267302_0

# %% [markdown]
# ### **Let's Begin:**

# %% [markdown]
# # **Data Exploration:**

# %% [markdown]
# **Lets start by importing the required libraries.**

# %%
# Basic python libraries.
import datetime
import numpy as np
import os
import tensorflow as tf
import matplotlib.pyplot as plt
from tqdm import tqdm
from PIL import Image
import itertools

# Get rid of warnings!
import warnings
warnings.filterwarnings('ignore')

# Deep learning libraries.
from sklearn.metrics import confusion_matrix
from tensorflow.keras import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout
from keras.optimizers import SGD

print('Above libraries have been imported.')
# Out:
# Above libraries have been imported.

# %%
# Define the train and validataion data paths.
train_dir = 'Dataset/train'
val_dir = 'Dataset/test'

# %% [markdown]
# **Seperate the Training and Validation Data.**

# %%
# Define the default image size.
img_size = 48

# Define the seven emotions provided in dataset.
emotion_list = ['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral']

# Plot the images with each distinct emotions.
plt.figure(figsize=(18,22))
i = 1
for expression in emotion_list:
    img = load_img((train_dir + '/' + expression +'/'+ os.listdir(train_dir + '/' + expression)[59]))
    plt.subplot(1,7,i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()

# %% [markdown]
# **Have a look at our data.**

# %% [markdown]
# **Perform some Data Augmentation on train and validations sets.**

# %%
def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    # SOURCE: https://jkjung-avt.github.io/keras-image-cropping/
    assert img.shape[2] == 3
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]

# %% [markdown]
# # **Data Preprocessing:**

# %%
# Rescale the data.
'''
Before we proceed we need to rescale our data by multiplying it to 1/255.
This is done so we get target values between 0 and 1.
'''
# Rescale train data.
datagen_train = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

# Rescale validation data.
datagen_val = ImageDataGenerator(rescale = 1./255,
                                 )

print('Above data generator functions have been created.')
# Out:
# Above data generator functions have been created.

# %%
# Perform data augmentation.
'''
Data augmentation is a technique to artificially create new training data from existing training data. 
It helps us to increase the size of the dataset and introduce variability in the dataset.
'''
# Define the default image size.
img_size = 48

# Define batch size.
batch_size = 64

                                         
# Train data
train_set = datagen_train.flow_from_directory(
    directory=train_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)

# Validation data
val_set = datagen_train.flow_from_directory(
    directory=val_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)


print('Train and Validation sets have been created.')
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.
# Train and Validation sets have been created.

# %% [markdown]
# **Now lets create our custom CNN model.**

# %% [markdown]
# # **Build CNN Model:**

# %% [markdown]
# **Before we start building the neural network lets understand some of the terms that we will be using.**
#
# * **Model = sequential** : A Sequential model is appropriate for a plain stack of layers where each layer has exactly one input tensor and one output tensor.
#
# * **Padding** = The padding parameter of the Keras Conv2D class can take one of two values: 'valid' or 'same'. Setting the value to “valid” parameter means that the input volume is not zero-padded and the spatial dimensions are allowed to reduce via the natural application of convolution.
#
# * **Activation** = relu :The rectified linear activation function or ReLU for short is a piecewise linear function that will output the input directly if it is positive, otherwise, it will output zero. It has become the default activation function for many types of neural networks because a model that uses it is easier to train and often achieves better performance.
#
# * **Maxpooling** = Maximum pooling, or max pooling, is a pooling operation that calculates the maximum, or largest, value in each patch of each feature map. The results are down sampled or pooled feature maps that highlight the most present feature in the patch, not the average presence of the feature in the case of average pooling.
#
# * **Batch normalization** = Batch normalization is a technique for training very deep neural networks that standardizes the inputs to a layer for each mini-batch. This has the effect of stabilizing the learning process and dramatically reducing the number of training epochs required to train deep networks.
#
# * **Dropout** = Dropout is a technique used to prevent a model from overfitting. Dropout works by randomly setting the outgoing edges of hidden units (neurons that make up hidden layers) to 0 at each update of the training phase.
#
# * **Adam** = Adaptive Moment Estimation is an algorithm for optimization technique for gradient descent. The method is really efficient when working with large problem involving a lot of data or parameters. It requires less memory and is efficient. Intuitively, it is a combination of the ‘gradient descent with momentum’ algorithm and the ‘RMSP’ algorithm. It uses the squared gradients to scale the learning rate like RMSprop and it takes advantage of momentum by using moving average of the gradient instead of gradient itself like SGD with momentum.

# %%
# AlexNet model

class AlexNet(Sequential):
  def __init__(self, input_shape, num_classes):
    super().__init__()

    self.add(Conv2D(64, kernel_size = (3,3),
                    strides= 2, 
                    padding = 'valid', 
                    activation = 'relu',
                    input_shape= input_shape,
                    kernel_initializer= 'he_normal'
                    ))
    
    self.add(MaxPooling2D(pool_size=(3,3), 
                          strides= (2,2),
                          padding= 'valid', 
                          data_format= None))

    self.add(Conv2D(128, kernel_size=(3,3), 
                    strides= 1,
                    padding= 'same', 
                    activation= 'relu',
                    kernel_initializer= 'he_normal'))
    
    self.add(MaxPooling2D(pool_size=(3,3), 
                          strides= (2,2),
                          padding= 'valid', 
                          data_format= None)) 

    self.add(Conv2D(256, kernel_size=(3,3), 
                    strides= 1,
                    padding= 'same', activation= 'relu',
                        kernel_initializer= 'he_normal'))
    
    self.add(MaxPooling2D(pool_size=(3,3), 
                          strides= (2,2),
                          padding= 'valid', 
                          data_format= None)) 

    self.add(Conv2D(512, kernel_size=(3,3), 
                    strides= 1,
                    padding= 'same', 
                    activation= 'relu',
                    kernel_initializer= 'he_normal'))

    self.add(MaxPooling2D(pool_size=(2,2), 
                          strides= (2,2),
                          padding= 'valid', 
                          data_format= None))

    self.add(Flatten())
    self.add(Dense(4096, activation= 'relu'))
    self.add(Dense(4096, activation= 'relu'))
    self.add(Dense(1000, activation= 'relu'))
    self.add(Dense(1000, activation= 'relu'))
    self.add(Dense(1000, activation= 'relu'))
    self.add(Dense(1000, activation= 'relu'))
    self.add(Dense(num_classes, activation= 'softmax'))

    opt = SGD(lr=0.01)
    self.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# %%
model = AlexNet((48,48,3),7)

epochs = 150
steps_per_epoch = train_set.n//train_set.batch_size
validation_steps = val_set.n//val_set.batch_size

history = model.fit(train_set,
                              steps_per_epoch=steps_per_epoch,
                              epochs=epochs,
                              batch_size = 32,
                              validation_data=val_set,
                              validation_steps=validation_steps)
# Out:
# Epoch 1/150
# 448/448 [==============================] - 163s 358ms/step - loss: 1.8171 - accuracy: 0.2489 - val_loss: 1.8103 - val_accuracy: 0.2475
# Epoch 2/150
# 448/448 [==============================] - 27s 61ms/step - loss: 1.8023 - accuracy: 0.2532 - val_loss: 1.8033 - val_accuracy: 0.2633
# Epoch 3/150
# 448/448 [==============================] - 26s 58ms/step - loss: 1.7879 - accuracy: 0.2603 - val_loss: 1.7738 - val_accuracy: 0.2606
# Epoch 4/150
# 448/448 [==============================] - 27s 59ms/step - loss: 1.7726 - accuracy: 0.2666 - val_loss: 1.7571 - val_accuracy: 0.2842
# Epoch 5/150
# 448/448 [==============================] - 27s 60ms/step - loss: 1.7505 - accuracy: 0.2848 - val_loss: 1.8212 - val_accuracy: 0.2352
# Epoch 6/150
# 448/448 [==============================] - 27s 61ms/step - loss: 1.7242 - accuracy: 0.3049 - val_loss: 1.6869 - val_accuracy: 0.3313
# Epoch 7/150
# 448/448 [==============================] - 26s 59ms/step - loss: 1.6914 - accuracy: 0.3236 - val_loss: 1.6818 - val_accuracy: 0.3359
# Epoch 8/150
# 448/448 [==============================] - 28s 62ms/step - loss: 1.6589 - accuracy: 0.3456 - val_loss: 1.6134 - val_accuracy: 0.3838
# Epoch 9/150
# 448/448 [==============================] - 27s 60ms/step - loss: 1.6256 - accuracy: 0.3659 - val_loss: 1.5767 - val_accuracy: 0.3902
# Epoch 10/150
# 448/448 [==============================] - 27s 60ms/step - loss: 1.5931 - accuracy: 0.3783 - val_loss: 1.7285 - val_accuracy: 0.3167
# Epoch 11/150
# 448/448 [==============================] - 27s 60ms/step - loss: 1.5662 - accuracy: 0.3898 - val_loss: 1.5701 - val_accuracy: 0.3878
# Epoch 12/150
# 448/448 [==============================] - 27s 60ms/step - loss: 1.5306 - accuracy: 0.4078 - val_loss: 1.5631 - val_accuracy: 0.4050
# Epoch 13/150
# 448/448 [==============================] - 27s 60ms/step - loss: 1.5111 - accuracy: 0.4152 - val_loss: 1.4896 - val_accuracy: 0.4298
# Epoch 14/150
# 448/448 [==============================] - 27s 60ms/step - loss: 1.4864 - accuracy: 0.4256 - val_loss: 1.4783 - val_accuracy: 0.4263
# Epoch 15/150
# 448/448 [==============================] - 27s 59ms/step - loss: 1.4677 - accuracy: 0.4369 - val_loss: 1.4627 - val_accuracy: 0.4350
# Epoch 16/150
# 448/448 [==============================] - 27s 60ms/step - loss: 1.4441 - accuracy: 0.4438 - val_loss: 1.4140 - val_accuracy: 0.4540
# Epoch 17/150
# 448/448 [==============================] - 28s 61ms/step - loss: 1.4300 - accuracy: 0.4507 - val_loss: 1.4299 - val_accuracy: 0.4530
# Epoch 18/150
# 448/448 [==============================] - 28s 62ms/step - loss: 1.4028 - accuracy: 0.4634 - val_loss: 1.3965 - val_accuracy: 0.4700
# Epoch 19/150
# 448/448 [==============================] - 27s 60ms/step - loss: 1.3962 - accuracy: 0.4646 - val_loss: 1.4171 - val_accuracy: 0.4534
# Epoch 20/150
# 448/448 [==============================] - 26s 57ms/step - loss: 1.3801 - accuracy: 0.4737 - val_loss: 1.4040 - val_accuracy: 0.4559
# Epoch 21/150
# 448/448 [==============================] - 27s 59ms/step - loss: 1.3574 - accuracy: 0.4807 - val_loss: 1.3580 - val_accuracy: 0.4863
# Epoch 22/150
# 448/448 [==============================] - 29s 64ms/step - loss: 1.3429 - accuracy: 0.4862 - val_loss: 1.3822 - val_accuracy: 0.4693
# Epoch 23/150
# 448/448 [==============================] - 29s 65ms/step - loss: 1.3348 - accuracy: 0.4920 - val_loss: 1.3644 - val_accuracy: 0.4732
# Epoch 24/150
# 448/448 [==============================] - 27s 59ms/step - loss: 1.3187 - accuracy: 0.4936 - val_loss: 1.3242 - val_accuracy: 0.4940
# Epoch 25/150
# 448/448 [==============================] - 27s 59ms/step - loss: 1.3039 - accuracy: 0.5020 - val_loss: 1.3118 - val_accuracy: 0.4934
# Epoch 26/150
# 448/448 [==============================] - 29s 64ms/step - loss: 1.2900 - accuracy: 0.5101 - val_loss: 1.2903 - val_accuracy: 0.5050
# Epoch 27/150
# 448/448 [==============================] - 27s 60ms/step - loss: 1.2829 - accuracy: 0.5108 - val_loss: 1.3042 - val_accuracy: 0.4947
# Epoch 28/150
# 448/448 [==============================] - 28s 61ms/step - loss: 1.2738 - accuracy: 0.5160 - val_loss: 1.3388 - val_accuracy: 0.4844
# Epoch 29/150
# 448/448 [==============================] - 27s 61ms/step - loss: 1.2620 - accuracy: 0.5186 - val_loss: 1.2827 - val_accuracy: 0.5096
# Epoch 30/150
# 448/448 [==============================] - 27s 61ms/step - loss: 1.2548 - accuracy: 0.5230 - val_loss: 1.2750 - val_accuracy: 0.5117
# Epoch 31/150
# 448/448 [==============================] - 28s 62ms/step - loss: 1.2367 - accuracy: 0.5324 - val_loss: 1.2575 - val_accuracy: 0.5226
# Epoch 32/150
# 448/448 [==============================] - 27s 61ms/step - loss: 1.2326 - accuracy: 0.5306 - val_loss: 1.2762 - val_accuracy: 0.5086
# Epoch 33/150
# 448/448 [==============================] - 27s 60ms/step - loss: 1.2214 - accuracy: 0.5395 - val_loss: 1.2897 - val_accuracy: 0.5102
# Epoch 34/150
# 448/448 [==============================] - 28s 61ms/step - loss: 1.2099 - accuracy: 0.5397 - val_loss: 1.2431 - val_accuracy: 0.5280
# Epoch 35/150
# 448/448 [==============================] - 29s 64ms/step - loss: 1.2014 - accuracy: 0.5428 - val_loss: 1.2497 - val_accuracy: 0.5262
# Epoch 36/150
# 448/448 [==============================] - 26s 59ms/step - loss: 1.1928 - accuracy: 0.5492 - val_loss: 1.2352 - val_accuracy: 0.5336
# Epoch 37/150
# 448/448 [==============================] - 26s 57ms/step - loss: 1.1854 - accuracy: 0.5497 - val_loss: 1.2609 - val_accuracy: 0.5197
# Epoch 38/150
# 448/448 [==============================] - 26s 58ms/step - loss: 1.1751 - accuracy: 0.5535 - val_loss: 1.2468 - val_accuracy: 0.5248
# Epoch 39/150
# 448/448 [==============================] - 27s 60ms/step - loss: 1.1733 - accuracy: 0.5534 - val_loss: 1.2376 - val_accuracy: 0.5293
# Epoch 40/150
# 448/448 [==============================] - 29s 66ms/step - loss: 1.1635 - accuracy: 0.5595 - val_loss: 1.2236 - val_accuracy: 0.5375
# Epoch 41/150
# 448/448 [==============================] - 31s 69ms/step - loss: 1.1537 - accuracy: 0.5619 - val_loss: 1.2128 - val_accuracy: 0.5377
# Epoch 42/150
# 448/448 [==============================] - 29s 65ms/step - loss: 1.1445 - accuracy: 0.5661 - val_loss: 1.2147 - val_accuracy: 0.5439
# Epoch 43/150
# 448/448 [==============================] - 28s 63ms/step - loss: 1.1376 - accuracy: 0.5723 - val_loss: 1.2223 - val_accuracy: 0.5343
# Epoch 44/150
# 448/448 [==============================] - 29s 64ms/step - loss: 1.1295 - accuracy: 0.5744 - val_loss: 1.2395 - val_accuracy: 0.5297
# Epoch 45/150
# 448/448 [==============================] - 26s 59ms/step - loss: 1.1239 - accuracy: 0.5746 - val_loss: 1.2490 - val_accuracy: 0.5301
# Epoch 46/150
# 448/448 [==============================] - 27s 59ms/step - loss: 1.1166 - accuracy: 0.5802 - val_loss: 1.1831 - val_accuracy: 0.5516
# Epoch 47/150
# 448/448 [==============================] - 26s 59ms/step - loss: 1.1119 - accuracy: 0.5805 - val_loss: 1.1970 - val_accuracy: 0.5413
# Epoch 48/150
# 448/448 [==============================] - 27s 60ms/step - loss: 1.1047 - accuracy: 0.5781 - val_loss: 1.2121 - val_accuracy: 0.5364
# Epoch 49/150
# 448/448 [==============================] - 27s 60ms/step - loss: 1.0965 - accuracy: 0.5883 - val_loss: 1.1865 - val_accuracy: 0.5530
# Epoch 50/150
# 448/448 [==============================] - 27s 61ms/step - loss: 1.0868 - accuracy: 0.5913 - val_loss: 1.1818 - val_accuracy: 0.5523
# Epoch 51/150
# 448/448 [==============================] - 27s 61ms/step - loss: 1.0851 - accuracy: 0.5914 - val_loss: 1.2018 - val_accuracy: 0.5449
# Epoch 52/150
# 448/448 [==============================] - 28s 62ms/step - loss: 1.0730 - accuracy: 0.5957 - val_loss: 1.1704 - val_accuracy: 0.5583
# Epoch 53/150
# 448/448 [==============================] - 27s 60ms/step - loss: 1.0633 - accuracy: 0.5990 - val_loss: 1.1549 - val_accuracy: 0.5657
# Epoch 54/150
# 448/448 [==============================] - 27s 59ms/step - loss: 1.0642 - accuracy: 0.5987 - val_loss: 1.2070 - val_accuracy: 0.5488
# Epoch 55/150
# 448/448 [==============================] - 27s 61ms/step - loss: 1.0481 - accuracy: 0.6067 - val_loss: 1.1592 - val_accuracy: 0.5639
# Epoch 56/150
# 448/448 [==============================] - 27s 59ms/step - loss: 1.0466 - accuracy: 0.6059 - val_loss: 1.1605 - val_accuracy: 0.5622
# Epoch 57/150
# 448/448 [==============================] - 26s 59ms/step - loss: 1.0408 - accuracy: 0.6096 - val_loss: 1.1724 - val_accuracy: 0.5618
# Epoch 58/150
# 448/448 [==============================] - 27s 59ms/step - loss: 1.0348 - accuracy: 0.6091 - val_loss: 1.2142 - val_accuracy: 0.5488
# Epoch 59/150
# 448/448 [==============================] - 27s 59ms/step - loss: 1.0275 - accuracy: 0.6108 - val_loss: 1.2381 - val_accuracy: 0.5197
# Epoch 60/150
# 448/448 [==============================] - 27s 59ms/step - loss: 1.0141 - accuracy: 0.6202 - val_loss: 1.2161 - val_accuracy: 0.5409
# Epoch 61/150
# 448/448 [==============================] - 27s 60ms/step - loss: 1.0145 - accuracy: 0.6204 - val_loss: 1.1728 - val_accuracy: 0.5583
# Epoch 62/150
# 448/448 [==============================] - 28s 63ms/step - loss: 1.0059 - accuracy: 0.6235 - val_loss: 1.1870 - val_accuracy: 0.5582
# Epoch 63/150
# 448/448 [==============================] - 33s 73ms/step - loss: 0.9999 - accuracy: 0.6248 - val_loss: 1.1756 - val_accuracy: 0.5645
# Epoch 64/150
# 448/448 [==============================] - 26s 58ms/step - loss: 0.9942 - accuracy: 0.6290 - val_loss: 1.1912 - val_accuracy: 0.5585
# Epoch 65/150
# 448/448 [==============================] - 26s 57ms/step - loss: 0.9847 - accuracy: 0.6337 - val_loss: 1.1724 - val_accuracy: 0.5582
# Epoch 66/150
# 448/448 [==============================] - 26s 58ms/step - loss: 0.9742 - accuracy: 0.6355 - val_loss: 1.1719 - val_accuracy: 0.5691
# Epoch 67/150
# 448/448 [==============================] - 26s 57ms/step - loss: 0.9736 - accuracy: 0.6340 - val_loss: 1.1398 - val_accuracy: 0.5763
# Epoch 68/150
# 448/448 [==============================] - 26s 59ms/step - loss: 0.9574 - accuracy: 0.6384 - val_loss: 1.1974 - val_accuracy: 0.5575
# Epoch 69/150
# 448/448 [==============================] - 27s 59ms/step - loss: 0.9510 - accuracy: 0.6440 - val_loss: 1.1730 - val_accuracy: 0.5647
# Epoch 70/150
# 448/448 [==============================] - 26s 58ms/step - loss: 0.9476 - accuracy: 0.6431 - val_loss: 1.1420 - val_accuracy: 0.5767
# Epoch 71/150
# 448/448 [==============================] - 27s 60ms/step - loss: 0.9414 - accuracy: 0.6470 - val_loss: 1.1374 - val_accuracy: 0.5770
# Epoch 72/150
# 448/448 [==============================] - 28s 62ms/step - loss: 0.9418 - accuracy: 0.6490 - val_loss: 1.1692 - val_accuracy: 0.5607
# Epoch 73/150
# 448/448 [==============================] - 27s 60ms/step - loss: 0.9297 - accuracy: 0.6524 - val_loss: 1.1945 - val_accuracy: 0.5689
# Epoch 74/150
# 448/448 [==============================] - 28s 61ms/step - loss: 0.9212 - accuracy: 0.6553 - val_loss: 1.2190 - val_accuracy: 0.5557
# Epoch 75/150
# 448/448 [==============================] - 28s 61ms/step - loss: 0.9184 - accuracy: 0.6542 - val_loss: 1.1713 - val_accuracy: 0.5692
# Epoch 76/150
# 448/448 [==============================] - 30s 67ms/step - loss: 0.9005 - accuracy: 0.6639 - val_loss: 1.1831 - val_accuracy: 0.5720
# Epoch 77/150
# 448/448 [==============================] - 31s 68ms/step - loss: 0.9084 - accuracy: 0.6615 - val_loss: 1.1312 - val_accuracy: 0.5854
# Epoch 78/150
# 448/448 [==============================] - 29s 65ms/step - loss: 0.8904 - accuracy: 0.6659 - val_loss: 1.1713 - val_accuracy: 0.5749
# Epoch 79/150
# 448/448 [==============================] - 30s 66ms/step - loss: 0.8867 - accuracy: 0.6717 - val_loss: 1.2003 - val_accuracy: 0.5628
# Epoch 80/150
# 448/448 [==============================] - 29s 66ms/step - loss: 0.8725 - accuracy: 0.6747 - val_loss: 1.2763 - val_accuracy: 0.5406
# Epoch 81/150
# 448/448 [==============================] - 31s 69ms/step - loss: 0.8715 - accuracy: 0.6765 - val_loss: 1.2029 - val_accuracy: 0.5732
# Epoch 82/150
# 448/448 [==============================] - 26s 59ms/step - loss: 0.8645 - accuracy: 0.6765 - val_loss: 1.1582 - val_accuracy: 0.5762
# Epoch 83/150
# 448/448 [==============================] - 26s 59ms/step - loss: 0.8512 - accuracy: 0.6851 - val_loss: 1.1970 - val_accuracy: 0.5760
# Epoch 84/150
# 448/448 [==============================] - 27s 60ms/step - loss: 0.8473 - accuracy: 0.6857 - val_loss: 1.1826 - val_accuracy: 0.5671
# Epoch 85/150
# 448/448 [==============================] - 30s 66ms/step - loss: 0.8395 - accuracy: 0.6902 - val_loss: 1.2357 - val_accuracy: 0.5672
# Epoch 86/150
# 448/448 [==============================] - 27s 59ms/step - loss: 0.8302 - accuracy: 0.6933 - val_loss: 1.1762 - val_accuracy: 0.5862
# Epoch 87/150
# 448/448 [==============================] - 27s 59ms/step - loss: 0.8235 - accuracy: 0.6939 - val_loss: 1.1592 - val_accuracy: 0.5890
# Epoch 88/150
# 448/448 [==============================] - 26s 58ms/step - loss: 0.8143 - accuracy: 0.6973 - val_loss: 1.1926 - val_accuracy: 0.5621
# Epoch 89/150
# 448/448 [==============================] - 28s 61ms/step - loss: 0.8043 - accuracy: 0.7031 - val_loss: 1.1894 - val_accuracy: 0.5827
# Epoch 90/150
# 448/448 [==============================] - 27s 60ms/step - loss: 0.7983 - accuracy: 0.7061 - val_loss: 1.2036 - val_accuracy: 0.5636
# Epoch 91/150
# 448/448 [==============================] - 26s 59ms/step - loss: 0.7932 - accuracy: 0.7079 - val_loss: 1.1925 - val_accuracy: 0.5824
# Epoch 92/150
# 448/448 [==============================] - 26s 59ms/step - loss: 0.7827 - accuracy: 0.7122 - val_loss: 1.1847 - val_accuracy: 0.5799
# Epoch 93/150
# 448/448 [==============================] - 26s 58ms/step - loss: 0.7738 - accuracy: 0.7142 - val_loss: 1.2395 - val_accuracy: 0.5615
# Epoch 94/150
# 448/448 [==============================] - 26s 58ms/step - loss: 0.7639 - accuracy: 0.7196 - val_loss: 1.2144 - val_accuracy: 0.5681
# Epoch 95/150
# 448/448 [==============================] - 26s 59ms/step - loss: 0.7598 - accuracy: 0.7210 - val_loss: 1.1888 - val_accuracy: 0.5827
# Epoch 96/150
# 448/448 [==============================] - 26s 58ms/step - loss: 0.7549 - accuracy: 0.7216 - val_loss: 1.1703 - val_accuracy: 0.5845
# Epoch 97/150
# 448/448 [==============================] - 26s 59ms/step - loss: 0.7379 - accuracy: 0.7296 - val_loss: 1.2541 - val_accuracy: 0.5573
# Epoch 98/150
# 448/448 [==============================] - 26s 58ms/step - loss: 0.7266 - accuracy: 0.7308 - val_loss: 1.3153 - val_accuracy: 0.5532
# Epoch 99/150
# 448/448 [==============================] - 26s 58ms/step - loss: 0.7284 - accuracy: 0.7299 - val_loss: 1.2210 - val_accuracy: 0.5836
# Epoch 100/150
# 448/448 [==============================] - 26s 58ms/step - loss: 0.7103 - accuracy: 0.7369 - val_loss: 1.2016 - val_accuracy: 0.5836
# Epoch 101/150
# 448/448 [==============================] - 26s 58ms/step - loss: 0.7039 - accuracy: 0.7407 - val_loss: 1.3224 - val_accuracy: 0.5777
# Epoch 102/150
# 448/448 [==============================] - 26s 58ms/step - loss: 0.7044 - accuracy: 0.7403 - val_loss: 1.2387 - val_accuracy: 0.5749
# Epoch 103/150
# 448/448 [==============================] - 26s 59ms/step - loss: 0.6870 - accuracy: 0.7492 - val_loss: 1.2282 - val_accuracy: 0.5907
# Epoch 104/150
# 448/448 [==============================] - 27s 61ms/step - loss: 0.6818 - accuracy: 0.7498 - val_loss: 1.2961 - val_accuracy: 0.5765
# Epoch 105/150
# 448/448 [==============================] - 26s 59ms/step - loss: 0.6780 - accuracy: 0.7509 - val_loss: 1.2592 - val_accuracy: 0.5831
# Epoch 106/150
# 448/448 [==============================] - 27s 59ms/step - loss: 0.6624 - accuracy: 0.7563 - val_loss: 1.2372 - val_accuracy: 0.5797
# Epoch 107/150
# 448/448 [==============================] - 27s 60ms/step - loss: 0.6491 - accuracy: 0.7637 - val_loss: 1.2663 - val_accuracy: 0.5876
# Epoch 108/150
# 448/448 [==============================] - 26s 58ms/step - loss: 0.6476 - accuracy: 0.7617 - val_loss: 1.3008 - val_accuracy: 0.5696
# Epoch 109/150
# 448/448 [==============================] - 27s 59ms/step - loss: 0.6396 - accuracy: 0.7657 - val_loss: 1.2276 - val_accuracy: 0.5925
# Epoch 110/150
# 448/448 [==============================] - 34s 76ms/step - loss: 0.6275 - accuracy: 0.7730 - val_loss: 1.4341 - val_accuracy: 0.5439
# Epoch 111/150
# 448/448 [==============================] - 38s 85ms/step - loss: 0.6197 - accuracy: 0.7744 - val_loss: 1.2685 - val_accuracy: 0.5957
# Epoch 112/150
# 448/448 [==============================] - 42s 93ms/step - loss: 0.6137 - accuracy: 0.7745 - val_loss: 1.4349 - val_accuracy: 0.5541
# Epoch 113/150
# 448/448 [==============================] - 37s 82ms/step - loss: 0.6004 - accuracy: 0.7826 - val_loss: 1.3374 - val_accuracy: 0.5815
# Epoch 114/150
# 448/448 [==============================] - 35s 79ms/step - loss: 0.5905 - accuracy: 0.7862 - val_loss: 1.3727 - val_accuracy: 0.5532
# Epoch 115/150
# 448/448 [==============================] - 45s 99ms/step - loss: 0.5862 - accuracy: 0.7857 - val_loss: 1.3138 - val_accuracy: 0.5928
# Epoch 116/150
# 448/448 [==============================] - 37s 83ms/step - loss: 0.5723 - accuracy: 0.7925 - val_loss: 1.2832 - val_accuracy: 0.5824
# Epoch 117/150
# 448/448 [==============================] - 26s 58ms/step - loss: 0.5684 - accuracy: 0.7938 - val_loss: 1.3042 - val_accuracy: 0.5970
# Epoch 118/150
# 448/448 [==============================] - 26s 59ms/step - loss: 0.5496 - accuracy: 0.7980 - val_loss: 1.3981 - val_accuracy: 0.5773
# Epoch 119/150
# 448/448 [==============================] - 34s 75ms/step - loss: 0.5563 - accuracy: 0.7963 - val_loss: 1.3405 - val_accuracy: 0.5794
# Epoch 120/150
# 448/448 [==============================] - 29s 64ms/step - loss: 0.5430 - accuracy: 0.8028 - val_loss: 1.3798 - val_accuracy: 0.5802
# Epoch 121/150
# 448/448 [==============================] - 28s 62ms/step - loss: 0.5342 - accuracy: 0.8043 - val_loss: 1.4302 - val_accuracy: 0.5603
# Epoch 122/150
# 448/448 [==============================] - 26s 58ms/step - loss: 0.5239 - accuracy: 0.8098 - val_loss: 1.2844 - val_accuracy: 0.5928
# Epoch 123/150
# 448/448 [==============================] - 27s 59ms/step - loss: 0.5073 - accuracy: 0.8170 - val_loss: 1.3701 - val_accuracy: 0.5625
# Epoch 124/150
# 448/448 [==============================] - 27s 60ms/step - loss: 0.5031 - accuracy: 0.8188 - val_loss: 1.4073 - val_accuracy: 0.5615
# Epoch 125/150
# 448/448 [==============================] - 27s 59ms/step - loss: 0.5056 - accuracy: 0.8150 - val_loss: 1.4108 - val_accuracy: 0.5735
# Epoch 126/150
# 448/448 [==============================] - 28s 61ms/step - loss: 0.4894 - accuracy: 0.8237 - val_loss: 1.3696 - val_accuracy: 0.5866
# Epoch 127/150
# 448/448 [==============================] - 27s 61ms/step - loss: 0.4876 - accuracy: 0.8230 - val_loss: 1.3624 - val_accuracy: 0.5981
# Epoch 128/150
# 448/448 [==============================] - 26s 59ms/step - loss: 0.4748 - accuracy: 0.8296 - val_loss: 1.4171 - val_accuracy: 0.5816
# Epoch 129/150
# 448/448 [==============================] - 26s 58ms/step - loss: 0.4690 - accuracy: 0.8274 - val_loss: 1.4828 - val_accuracy: 0.5795
# Epoch 130/150
# 448/448 [==============================] - 26s 58ms/step - loss: 0.4633 - accuracy: 0.8322 - val_loss: 1.3855 - val_accuracy: 0.5985
# Epoch 131/150
# 448/448 [==============================] - 26s 58ms/step - loss: 0.4501 - accuracy: 0.8390 - val_loss: 1.4668 - val_accuracy: 0.5903
# Epoch 132/150
# 448/448 [==============================] - 27s 59ms/step - loss: 0.4388 - accuracy: 0.8418 - val_loss: 1.4525 - val_accuracy: 0.5897
# Epoch 133/150
# 448/448 [==============================] - 26s 58ms/step - loss: 0.4290 - accuracy: 0.8465 - val_loss: 1.5149 - val_accuracy: 0.5852
# Epoch 134/150
# 448/448 [==============================] - 26s 58ms/step - loss: 0.4264 - accuracy: 0.8464 - val_loss: 1.4191 - val_accuracy: 0.5928
# Epoch 135/150
# 448/448 [==============================] - 26s 59ms/step - loss: 0.4178 - accuracy: 0.8485 - val_loss: 1.4450 - val_accuracy: 0.5997
# Epoch 136/150
# 448/448 [==============================] - 26s 58ms/step - loss: 0.4082 - accuracy: 0.8521 - val_loss: 1.4878 - val_accuracy: 0.5854
# Epoch 137/150
# 448/448 [==============================] - 26s 58ms/step - loss: 0.3995 - accuracy: 0.8546 - val_loss: 1.5863 - val_accuracy: 0.5732
# Epoch 138/150
# 448/448 [==============================] - 27s 60ms/step - loss: 0.3911 - accuracy: 0.8576 - val_loss: 1.5116 - val_accuracy: 0.5878
# Epoch 139/150
# 448/448 [==============================] - 26s 59ms/step - loss: 0.3850 - accuracy: 0.8589 - val_loss: 1.5055 - val_accuracy: 0.5850
# Epoch 140/150
# 448/448 [==============================] - 27s 59ms/step - loss: 0.3851 - accuracy: 0.8588 - val_loss: 1.4847 - val_accuracy: 0.5964
# Epoch 141/150
# 448/448 [==============================] - 26s 59ms/step - loss: 0.3734 - accuracy: 0.8640 - val_loss: 1.5831 - val_accuracy: 0.5984
# Epoch 142/150
# 448/448 [==============================] - 26s 58ms/step - loss: 0.3640 - accuracy: 0.8682 - val_loss: 1.5014 - val_accuracy: 0.5970
# Epoch 143/150
# 448/448 [==============================] - 26s 58ms/step - loss: 0.3589 - accuracy: 0.8693 - val_loss: 1.5837 - val_accuracy: 0.5868
# Epoch 144/150
# 448/448 [==============================] - 27s 59ms/step - loss: 0.3516 - accuracy: 0.8733 - val_loss: 1.6743 - val_accuracy: 0.5784
# Epoch 145/150
# 448/448 [==============================] - 26s 59ms/step - loss: 0.3436 - accuracy: 0.8748 - val_loss: 1.6724 - val_accuracy: 0.5790
# Epoch 146/150
# 448/448 [==============================] - 27s 61ms/step - loss: 0.3362 - accuracy: 0.8802 - val_loss: 1.6138 - val_accuracy: 0.5939
# Epoch 147/150
# 448/448 [==============================] - 28s 62ms/step - loss: 0.3301 - accuracy: 0.8810 - val_loss: 1.5577 - val_accuracy: 0.5970
# Epoch 148/150
# 448/448 [==============================] - 27s 60ms/step - loss: 0.3201 - accuracy: 0.8853 - val_loss: 1.6304 - val_accuracy: 0.5822
# Epoch 149/150
# 448/448 [==============================] - 27s 59ms/step - loss: 0.3137 - accuracy: 0.8878 - val_loss: 1.5581 - val_accuracy: 0.5864
# Epoch 150/150
# 448/448 [==============================] - 27s 59ms/step - loss: 0.3103 - accuracy: 0.8899 - val_loss: 1.5250 - val_accuracy: 0.5911

# %% [markdown]
# #Save model

# %%
label_dict = {0:'Angry',1:'Disgust',2:'Fear',3:'Happy',4:'Neutral',5:'Sad',6:'Surprise'}

def predict(img_dir):
  img = load_img(img_dir,target_size = (48,48),color_mode = "rgb")
  img = np.array(img)
  img = np.expand_dims(img,axis = 0) # Makes image shape (1,48,48)
  img = img.reshape(1,48,48,3)
  result = model.predict(img)
  result = list(result[0])
  img_index = result.index(max(result))
  return label_dict[img_index]

result = predict("/content/test/happy/PrivateTest_10513598.jpg")
print(result)

# %%
model_dir = "AlexNet_model_iters150.h5"
model_weights_dir = "AlexNet_model_weighs_iters150.h5"

# %%
# Save the whole model
model.save(model_dir)
model.save_weights(model_weights_dir)

# %% [markdown]
# # **Model evaluation:**

# %%
# Using Tensorboard 
# %tensorboard --logdir logs/fit

# %%
# Or using plotting 
# Create plots for accuracy and loss.
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
fig.set_size_inches(12,4)

ax[0].plot(history.history['accuracy'])
ax[0].plot(history.history['val_accuracy'])
ax[0].set_title('Training Accuracy vs Validation Accuracy')
ax[0].set_ylabel('Accuracy')
ax[0].set_xlabel('Epoch')
ax[0].legend(['Train', 'Validation'], loc='upper left')

ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[1].set_title('Training Loss vs Validation Loss')
ax[1].set_ylabel('Loss')
ax[1].set_xlabel('Epoch')
ax[1].legend(['Train', 'Validation'], loc='upper left')

plt.show()

# %%
# Create confusion matrix of our predictions

# compute predictions
predictions = model.predict_generator(generator=val_set)
y_pred = [np.argmax(probas) for probas in predictions]
y_test = val_set.classes
class_names = val_set.class_indices.keys()

# Create function to plot confussion matrix.
def plot_confusion_matrix(cm, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    plt.figure(figsize=(12,6), dpi=120)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')# **Live Class Monitoring System(Face Emotion Recognition)**
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.show()
    
# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, title='Normalized confusion matrix')
plt.show()

# %% [markdown]
# ## Pretrain Model

# %% [markdown]
# Load model:

# %% [markdown]
# loaded_model = load_model("AlexNet_model-100iters.h5")
# loaded_model.load_weights("AlexNet_model_weights-100iters.h5")
