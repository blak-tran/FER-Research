# %% [markdown]
# <a href="https://colab.research.google.com/github/anishjohnson/Face-Emotion-Recognition/blob/main/FER/Colab%20Notebook/Face_Emotion_Recognition_Anish_Johnson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Face Emotion Recognition**

# %% [markdown]
# # **Objective**
# Our objective is to solve the above mentioned challenge by applying deep learning algorithms to live video data inorder to recognize the facial emotions and categorize them accordingly.

# %% [markdown]
# # **Dataset used**
# We have utilized the [FER 2013](https://www.kaggle.com/datasets/msambare/fer2013) dataset provided on Kaggle.<br>
# The data consists of 48x48 pixel grayscale images of faces. The faces have been automatically registered so that the face is more or less centred and occupies about the same amount of space in each image.<br>
#
# The task is to categorize each face based on the emotion shown in the facial expression into one of seven categories (0=Angry, 1=Disgust, 2=Fear, 3=Happy, 4=Sad, 5=Surprise, 6=Neutral). The training set consists of 28,709 examples and the public test set consists of 3,589 examples.

# %%
# !nvidia-smi
# !nvcc -V
# Out:
# Fri Feb 24 16:49:56 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.47.03    Driver Version: 510.47.03    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   51C    P0    28W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Tue_Mar__8_18:18:20_PST_2022
# Cuda compilation tools, release 11.6, V11.6.124
# Build cuda_11.6.r11.6/compiler.31057947_0

# %% [markdown]
# ### **Let's Begin:**

# %% [markdown]
# # **Data Exploration:**

# %% [markdown]
# **Lets start by importing the required libraries.**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Basic python libraries.
import datetime
import numpy as np
import os
import tensorflow as tf
import matplotlib.pyplot as plt
from tqdm import tqdm
from PIL import Image
import itertools

# Get rid of warnings!
import warnings
warnings.filterwarnings('ignore')

# Deep learning libraries.
from sklearn.metrics import confusion_matrix
from tensorflow.keras import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout,BatchNormalization,Activation
from keras.optimizers import SGD
from keras.applications.nasnet import NASNetLarge
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from tensorflow.keras.applications import ResNet50

print('Above libraries have been imported.')
# Out:
# Above libraries have been imported.

# %% [markdown]
# **Seperate the Training and Validation Data.**

# %%
tf.__version__
# Out:
# '2.11.0'

# %%
file_path = '/content/drive/My Drive/Colab Notebooks/transfer_model/Dataset/FER-2013-Dataset.zip'

# %%
 from zipfile import ZipFile
 with ZipFile(file_path , 'r') as ZipFile:
   ZipFile.extractall()
   print('Zip file extracted successfully')
# Out:
# Zip file extracted successfully

# %%
# Define the train and validataion data paths.
train_dir = '/content/train'
val_dir = '/content/test'

# %%
# Define the default image size.
img_size = 48

# Define the seven emotions provided in dataset.
emotion_list = ['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral']

# Plot the images with each distinct emotions.
plt.figure(figsize=(18,22))
i = 1
for expression in emotion_list:
    img = load_img((train_dir + '/' + expression +'/'+ os.listdir(train_dir + '/' + expression)[59]))
    plt.subplot(1,7,i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()

# %% [markdown]
# **Have a look at our data.**

# %% [markdown]
# **Perform some Data Augmentation on train and validations sets.**

# %% [markdown]
# # **Data Preprocessing:**

# %%
# Rescale the data.
'''
Before we proceed we need to rescale our data by multiplying it to 1/255.
This is done so we get target values between 0 and 1.
'''
# Rescale train data.
datagen_train = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

# Rescale validation data.
datagen_val = ImageDataGenerator(rescale = 1./255,
                                 )

print('Above data generator functions have been created.')
# Out:
# Above data generator functions have been created.

# %%
# Perform data

'''
Data augmentation is a technique to artificially create new training data from existing training data. 
It helps us to increase the size of the dataset and introduce variability in the dataset.
'''
# Define the default image size.
img_size = 48

# Define batch size.
batch_size = 32

                                         
# Train data
train_set = datagen_train.flow_from_directory(
    directory=train_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    color_mode = 'rgb',
    class_mode='categorical',
    shuffle=True
)

# Validation data
val_set = datagen_train.flow_from_directory(
    directory=val_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    color_mode = 'rgb',
    class_mode='categorical',
    shuffle=False
)


print('Train and Validation sets have been created.')
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.
# Train and Validation sets have been created.

# %% [markdown]
# **Now lets create our custom CNN model.**

# %% [markdown]
# # **Build CNN Model:**

# %% [markdown]
# **Before we start building the neural network lets understand some of the terms that we will be using.**
#
# * **Model = sequential** : A Sequential model is appropriate for a plain stack of layers where each layer has exactly one input tensor and one output tensor.
#
# * **Padding** = The padding parameter of the Keras Conv2D class can take one of two values: 'valid' or 'same'. Setting the value to “valid” parameter means that the input volume is not zero-padded and the spatial dimensions are allowed to reduce via the natural application of convolution.
#
# * **Activation** = relu :The rectified linear activation function or ReLU for short is a piecewise linear function that will output the input directly if it is positive, otherwise, it will output zero. It has become the default activation function for many types of neural networks because a model that uses it is easier to train and often achieves better performance.
#
# * **Maxpooling** = Maximum pooling, or max pooling, is a pooling operation that calculates the maximum, or largest, value in each patch of each feature map. The results are down sampled or pooled feature maps that highlight the most present feature in the patch, not the average presence of the feature in the case of average pooling.
#
# * **Batch normalization** = Batch normalization is a technique for training very deep neural networks that standardizes the inputs to a layer for each mini-batch. This has the effect of stabilizing the learning process and dramatically reducing the number of training epochs required to train deep networks.
#
# * **Dropout** = Dropout is a technique used to prevent a model from overfitting. Dropout works by randomly setting the outgoing edges of hidden units (neurons that make up hidden layers) to 0 at each update of the training phase.
#
# * **Adam** = Adaptive Moment Estimation is an algorithm for optimization technique for gradient descent. The method is really efficient when working with large problem involving a lot of data or parameters. It requires less memory and is efficient. Intuitively, it is a combination of the ‘gradient descent with momentum’ algorithm and the ‘RMSP’ algorithm. It uses the squared gradients to scale the learning rate like RMSprop and it takes advantage of momentum by using moving average of the gradient instead of gradient itself like SGD with momentum.

# %%
base_model = tf.keras.applications.ResNet50(input_shape=(48,48,3),include_top=False,weights="imagenet")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 5s 0us/step

# %%
for layer in base_model.layers[:-4]:
    layer.trainable=False

# %%
# Building Model

model=Sequential()
model.add(base_model)
model.add(Dropout(0.5))
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(7,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 2, 2, 2048)        23587712
#
#  dropout (Dropout)           (None, 2, 2, 2048)        0
#
#  flatten (Flatten)           (None, 8192)              0
#
#  batch_normalization (BatchN  (None, 8192)             32768
#  ormalization)
#
#  dense (Dense)               (None, 32)                262176
#
#  batch_normalization_1 (Batc  (None, 32)               128
#  hNormalization)
#
#  activation (Activation)     (None, 32)                0
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  batch_normalization_2 (Batc  (None, 32)               128
#  hNormalization)
#
#  activation_1 (Activation)   (None, 32)                0
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  batch_normalization_3 (Batc  (None, 32)               128
#  hNormalization)
#
#  activation_2 (Activation)   (None, 32)                0
#
#  dense_3 (Dense)             (None, 7)                 231
#
# =================================================================
# Total params: 23,885,383
# Trainable params: 1,335,815
# Non-trainable params: 22,549,568
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
from IPython.display import Image
plot_model(model, to_file='convnet.png', show_shapes=True,show_layer_names=True)
Image(filename='convnet.png')

# %%
METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc')
]

# %%
lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = 20,verbose = 1,factor = 0.50, min_lr = 1e-10)

mcp = ModelCheckpoint('model.h5')

es = EarlyStopping(verbose=1, patience=20)

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy',metrics=METRICS)

# %%
history=model.fit(train_set,validation_data=val_set,epochs = 50,verbose = 1,callbacks=[lrd,mcp,es])
# Out:
# Epoch 1/50
# 898/898 [==============================] - 75s 67ms/step - loss: 1.8768 - accuracy: 0.8558 - precision: 0.2189 - recall: 0.0036 - auc: 0.6222 - val_loss: 1.8077 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6466 - lr: 0.0010
# Epoch 2/50
# 898/898 [==============================] - 56s 62ms/step - loss: 1.8095 - accuracy: 0.8571 - precision: 0.2727 - recall: 2.0899e-04 - auc: 0.6513 - val_loss: 1.7940 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6639 - lr: 0.0010
# Epoch 3/50
# 898/898 [==============================] - 55s 61ms/step - loss: 1.7876 - accuracy: 0.8571 - precision: 0.4000 - recall: 5.5732e-04 - auc: 0.6670 - val_loss: 1.7728 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6815 - lr: 0.0010
# Epoch 4/50
# 898/898 [==============================] - 56s 62ms/step - loss: 1.7730 - accuracy: 0.8571 - precision: 0.4388 - recall: 0.0015 - auc: 0.6771 - val_loss: 1.7693 - val_accuracy: 0.8571 - val_precision: 0.5000 - val_recall: 4.1794e-04 - val_auc: 0.6834 - lr: 0.0010
# Epoch 5/50
# 898/898 [==============================] - 55s 61ms/step - loss: 1.7649 - accuracy: 0.8571 - precision: 0.4624 - recall: 0.0030 - auc: 0.6821 - val_loss: 1.7551 - val_accuracy: 0.8572 - val_precision: 0.5366 - val_recall: 0.0031 - val_auc: 0.6899 - lr: 0.0010
# Epoch 6/50
# 898/898 [==============================] - 55s 61ms/step - loss: 1.7580 - accuracy: 0.8571 - precision: 0.4948 - recall: 0.0050 - auc: 0.6872 - val_loss: 1.7578 - val_accuracy: 0.8571 - val_precision: 0.1667 - val_recall: 1.3931e-04 - val_auc: 0.6899 - lr: 0.0010
# Epoch 7/50
# 898/898 [==============================] - 55s 61ms/step - loss: 1.7465 - accuracy: 0.8573 - precision: 0.5283 - recall: 0.0107 - auc: 0.6933 - val_loss: 1.7485 - val_accuracy: 0.8572 - val_precision: 0.6000 - val_recall: 8.3589e-04 - val_auc: 0.6955 - lr: 0.0010
# Epoch 8/50
# 898/898 [==============================] - 55s 61ms/step - loss: 1.7511 - accuracy: 0.8571 - precision: 0.4949 - recall: 0.0068 - auc: 0.6917 - val_loss: 1.7516 - val_accuracy: 0.8569 - val_precision: 0.3030 - val_recall: 0.0014 - val_auc: 0.6924 - lr: 0.0010
# Epoch 9/50
# 898/898 [==============================] - 54s 60ms/step - loss: 1.7419 - accuracy: 0.8574 - precision: 0.5378 - recall: 0.0107 - auc: 0.6965 - val_loss: 1.7225 - val_accuracy: 0.8576 - val_precision: 0.5821 - val_recall: 0.0109 - val_auc: 0.7093 - lr: 0.0010
# Epoch 10/50
# 898/898 [==============================] - 54s 61ms/step - loss: 1.7359 - accuracy: 0.8572 - precision: 0.5085 - recall: 0.0157 - auc: 0.6999 - val_loss: 1.7121 - val_accuracy: 0.8576 - val_precision: 0.6364 - val_recall: 0.0068 - val_auc: 0.7137 - lr: 0.0010
# Epoch 11/50
# 898/898 [==============================] - 55s 61ms/step - loss: 1.7348 - accuracy: 0.8572 - precision: 0.5091 - recall: 0.0136 - auc: 0.7010 - val_loss: 1.7184 - val_accuracy: 0.8582 - val_precision: 0.6474 - val_recall: 0.0156 - val_auc: 0.7081 - lr: 0.0010
# Epoch 12/50
# 898/898 [==============================] - 54s 60ms/step - loss: 1.7307 - accuracy: 0.8573 - precision: 0.5192 - recall: 0.0184 - auc: 0.7030 - val_loss: 1.7180 - val_accuracy: 0.8583 - val_precision: 0.6707 - val_recall: 0.0153 - val_auc: 0.7102 - lr: 0.0010
# Epoch 13/50
# 898/898 [==============================] - 56s 62ms/step - loss: 1.7271 - accuracy: 0.8575 - precision: 0.5323 - recall: 0.0187 - auc: 0.7055 - val_loss: 1.7775 - val_accuracy: 0.8579 - val_precision: 0.5443 - val_recall: 0.0308 - val_auc: 0.6748 - lr: 0.0010
# Epoch 14/50
# 898/898 [==============================] - 55s 61ms/step - loss: 1.7260 - accuracy: 0.8575 - precision: 0.5362 - recall: 0.0181 - auc: 0.7054 - val_loss: 1.6997 - val_accuracy: 0.8577 - val_precision: 0.6250 - val_recall: 0.0098 - val_auc: 0.7220 - lr: 0.0010
# Epoch 15/50
# 898/898 [==============================] - 55s 61ms/step - loss: 1.7242 - accuracy: 0.8574 - precision: 0.5277 - recall: 0.0192 - auc: 0.7072 - val_loss: 1.8290 - val_accuracy: 0.8576 - val_precision: 0.5377 - val_recall: 0.0228 - val_auc: 0.6352 - lr: 0.0010
# Epoch 16/50
# 898/898 [==============================] - 55s 61ms/step - loss: 1.7184 - accuracy: 0.8576 - precision: 0.5353 - recall: 0.0230 - auc: 0.7106 - val_loss: 1.7381 - val_accuracy: 0.8562 - val_precision: 0.4737 - val_recall: 0.0591 - val_auc: 0.7049 - lr: 0.0010
# Epoch 17/50
# 898/898 [==============================] - 54s 60ms/step - loss: 1.7183 - accuracy: 0.8578 - precision: 0.5504 - recall: 0.0264 - auc: 0.7098 - val_loss: 1.6954 - val_accuracy: 0.8590 - val_precision: 0.5691 - val_recall: 0.0545 - val_auc: 0.7208 - lr: 0.0010
# Epoch 18/50
# 898/898 [==============================] - 54s 60ms/step - loss: 1.7165 - accuracy: 0.8579 - precision: 0.5558 - recall: 0.0281 - auc: 0.7099 - val_loss: 1.7601 - val_accuracy: 0.8538 - val_precision: 0.4471 - val_recall: 0.0984 - val_auc: 0.7023 - lr: 0.0010
# Epoch 19/50
# 898/898 [==============================] - 55s 61ms/step - loss: 1.7095 - accuracy: 0.8581 - precision: 0.5621 - recall: 0.0318 - auc: 0.7137 - val_loss: 1.6960 - val_accuracy: 0.8582 - val_precision: 0.6383 - val_recall: 0.0167 - val_auc: 0.7242 - lr: 0.0010
# Epoch 20/50
# 898/898 [==============================] - 54s 60ms/step - loss: 1.7155 - accuracy: 0.8578 - precision: 0.5422 - recall: 0.0276 - auc: 0.7115 - val_loss: 1.6923 - val_accuracy: 0.8589 - val_precision: 0.6485 - val_recall: 0.0265 - val_auc: 0.7246 - lr: 0.0010
# Epoch 21/50
# 898/898 [==============================] - 54s 61ms/step - loss: 1.7107 - accuracy: 0.8581 - precision: 0.5664 - recall: 0.0294 - auc: 0.7132 - val_loss: 1.7369 - val_accuracy: 0.8589 - val_precision: 0.6295 - val_recall: 0.0291 - val_auc: 0.7029 - lr: 0.0010
# Epoch 22/50
# 898/898 [==============================] - 55s 61ms/step - loss: 1.7079 - accuracy: 0.8579 - precision: 0.5461 - recall: 0.0312 - auc: 0.7154 - val_loss: 1.6772 - val_accuracy: 0.8591 - val_precision: 0.7426 - val_recall: 0.0209 - val_auc: 0.7324 - lr: 0.0010
# Epoch 23/50
# 898/898 [==============================] - 55s 61ms/step - loss: 1.7072 - accuracy: 0.8580 - precision: 0.5472 - recall: 0.0333 - auc: 0.7154 - val_loss: 1.7007 - val_accuracy: 0.8591 - val_precision: 0.5450 - val_recall: 0.0834 - val_auc: 0.7218 - lr: 0.0010
# Epoch 24/50
# 898/898 [==============================] - 55s 61ms/step - loss: 1.7067 - accuracy: 0.8580 - precision: 0.5548 - recall: 0.0321 - auc: 0.7158 - val_loss: 1.6748 - val_accuracy: 0.8594 - val_precision: 0.7317 - val_recall: 0.0251 - val_auc: 0.7327 - lr: 0.0010
# Epoch 25/50
# 898/898 [==============================] - 55s 61ms/step - loss: 1.7029 - accuracy: 0.8582 - precision: 0.5613 - recall: 0.0343 - auc: 0.7182 - val_loss: 1.6892 - val_accuracy: 0.8576 - val_precision: 0.6016 - val_recall: 0.0103 - val_auc: 0.7293 - lr: 0.0010
# Epoch 26/50
# 898/898 [==============================] - 56s 62ms/step - loss: 1.7022 - accuracy: 0.8580 - precision: 0.5506 - recall: 0.0326 - auc: 0.7188 - val_loss: 1.6830 - val_accuracy: 0.8589 - val_precision: 0.6746 - val_recall: 0.0237 - val_auc: 0.7299 - lr: 0.0010
# Epoch 27/50
# 898/898 [==============================] - 55s 62ms/step - loss: 1.7012 - accuracy: 0.8582 - precision: 0.5662 - recall: 0.0331 - auc: 0.7189 - val_loss: 1.6918 - val_accuracy: 0.8597 - val_precision: 0.7065 - val_recall: 0.0305 - val_auc: 0.7243 - lr: 0.0010
# Epoch 28/50
# 898/898 [==============================] - 55s 62ms/step - loss: 1.7014 - accuracy: 0.8581 - precision: 0.5540 - recall: 0.0352 - auc: 0.7192 - val_loss: 1.6800 - val_accuracy: 0.8591 - val_precision: 0.6387 - val_recall: 0.0308 - val_auc: 0.7303 - lr: 0.0010
# Epoch 29/50
# 898/898 [==============================] - 56s 62ms/step - loss: 1.7045 - accuracy: 0.8580 - precision: 0.5512 - recall: 0.0330 - auc: 0.7170 - val_loss: 1.7029 - val_accuracy: 0.8569 - val_precision: 0.4964 - val_recall: 0.1060 - val_auc: 0.7237 - lr: 0.0010
# Epoch 30/50
# 898/898 [==============================] - 56s 62ms/step - loss: 1.6964 - accuracy: 0.8583 - precision: 0.5561 - recall: 0.0395 - auc: 0.7216 - val_loss: 1.6794 - val_accuracy: 0.8590 - val_precision: 0.6955 - val_recall: 0.0235 - val_auc: 0.7314 - lr: 0.0010
# Epoch 31/50
# 898/898 [==============================] - 56s 62ms/step - loss: 1.6977 - accuracy: 0.8584 - precision: 0.5650 - recall: 0.0392 - auc: 0.7203 - val_loss: 1.6824 - val_accuracy: 0.8595 - val_precision: 0.5567 - val_recall: 0.0807 - val_auc: 0.7305 - lr: 0.0010
# Epoch 32/50
# 898/898 [==============================] - 55s 61ms/step - loss: 1.6961 - accuracy: 0.8588 - precision: 0.5923 - recall: 0.0379 - auc: 0.7216 - val_loss: 1.6785 - val_accuracy: 0.8599 - val_precision: 0.6391 - val_recall: 0.0442 - val_auc: 0.7298 - lr: 0.0010
# Epoch 33/50
# 898/898 [==============================] - 56s 62ms/step - loss: 1.6966 - accuracy: 0.8584 - precision: 0.5642 - recall: 0.0378 - auc: 0.7216 - val_loss: 1.6765 - val_accuracy: 0.8593 - val_precision: 0.7350 - val_recall: 0.0240 - val_auc: 0.7340 - lr: 0.0010
# Epoch 34/50
# 898/898 [==============================] - 56s 62ms/step - loss: 1.6967 - accuracy: 0.8584 - precision: 0.5634 - recall: 0.0401 - auc: 0.7212 - val_loss: 1.7018 - val_accuracy: 0.8603 - val_precision: 0.6667 - val_recall: 0.0437 - val_auc: 0.7183 - lr: 0.0010
# Epoch 35/50
# 898/898 [==============================] - 55s 61ms/step - loss: 1.6944 - accuracy: 0.8588 - precision: 0.5824 - recall: 0.0397 - auc: 0.7223 - val_loss: 1.6712 - val_accuracy: 0.8603 - val_precision: 0.5963 - val_recall: 0.0681 - val_auc: 0.7331 - lr: 0.0010
# Epoch 36/50
# 898/898 [==============================] - 54s 61ms/step - loss: 1.6935 - accuracy: 0.8581 - precision: 0.5485 - recall: 0.0384 - auc: 0.7228 - val_loss: 1.6659 - val_accuracy: 0.8590 - val_precision: 0.7300 - val_recall: 0.0203 - val_auc: 0.7391 - lr: 0.0010
# Epoch 37/50
# 898/898 [==============================] - 55s 61ms/step - loss: 1.6891 - accuracy: 0.8585 - precision: 0.5613 - recall: 0.0432 - auc: 0.7247 - val_loss: 1.6730 - val_accuracy: 0.8600 - val_precision: 0.6316 - val_recall: 0.0485 - val_auc: 0.7323 - lr: 0.0010
# Epoch 38/50
# 898/898 [==============================] - 56s 62ms/step - loss: 1.6883 - accuracy: 0.8585 - precision: 0.5612 - recall: 0.0436 - auc: 0.7250 - val_loss: 1.6703 - val_accuracy: 0.8613 - val_precision: 0.6057 - val_recall: 0.0826 - val_auc: 0.7346 - lr: 0.0010
# Epoch 39/50
# 898/898 [==============================] - 56s 62ms/step - loss: 1.6927 - accuracy: 0.8587 - precision: 0.5755 - recall: 0.0425 - auc: 0.7225 - val_loss: 1.6893 - val_accuracy: 0.8595 - val_precision: 0.7222 - val_recall: 0.0272 - val_auc: 0.7263 - lr: 0.0010
# Epoch 40/50
# 898/898 [==============================] - 56s 62ms/step - loss: 1.6954 - accuracy: 0.8585 - precision: 0.5689 - recall: 0.0391 - auc: 0.7222 - val_loss: 1.6651 - val_accuracy: 0.8600 - val_precision: 0.6659 - val_recall: 0.0397 - val_auc: 0.7377 - lr: 0.0010
# Epoch 41/50
# 898/898 [==============================] - 55s 61ms/step - loss: 1.6902 - accuracy: 0.8584 - precision: 0.5560 - recall: 0.0425 - auc: 0.7241 - val_loss: 1.6730 - val_accuracy: 0.8590 - val_precision: 0.6955 - val_recall: 0.0235 - val_auc: 0.7339 - lr: 0.0010
# Epoch 42/50
# 898/898 [==============================] - 55s 61ms/step - loss: 1.6859 - accuracy: 0.8590 - precision: 0.5818 - recall: 0.0454 - auc: 0.7263 - val_loss: 1.6554 - val_accuracy: 0.8608 - val_precision: 0.6477 - val_recall: 0.0556 - val_auc: 0.7409 - lr: 0.0010
# Epoch 43/50
# 898/898 [==============================] - 55s 62ms/step - loss: 1.6912 - accuracy: 0.8584 - precision: 0.5569 - recall: 0.0424 - auc: 0.7237 - val_loss: 1.6641 - val_accuracy: 0.8592 - val_precision: 0.7419 - val_recall: 0.0224 - val_auc: 0.7411 - lr: 0.0010
# Epoch 44/50
# 898/898 [==============================] - 55s 61ms/step - loss: 1.6908 - accuracy: 0.8585 - precision: 0.5608 - recall: 0.0426 - auc: 0.7245 - val_loss: 1.6673 - val_accuracy: 0.8588 - val_precision: 0.7243 - val_recall: 0.0187 - val_auc: 0.7388 - lr: 0.0010
# Epoch 45/50
# 898/898 [==============================] - 56s 62ms/step - loss: 1.6873 - accuracy: 0.8587 - precision: 0.5707 - recall: 0.0441 - auc: 0.7255 - val_loss: 1.6591 - val_accuracy: 0.8601 - val_precision: 0.6770 - val_recall: 0.0394 - val_auc: 0.7414 - lr: 0.0010
# Epoch 46/50
# 898/898 [==============================] - 57s 63ms/step - loss: 1.6848 - accuracy: 0.8589 - precision: 0.5714 - recall: 0.0485 - auc: 0.7271 - val_loss: 1.6837 - val_accuracy: 0.8586 - val_precision: 0.7056 - val_recall: 0.0177 - val_auc: 0.7308 - lr: 0.0010
# Epoch 47/50
# 898/898 [==============================] - 54s 60ms/step - loss: 1.6816 - accuracy: 0.8591 - precision: 0.5825 - recall: 0.0489 - auc: 0.7279 - val_loss: 1.6573 - val_accuracy: 0.8614 - val_precision: 0.7032 - val_recall: 0.0518 - val_auc: 0.7403 - lr: 0.0010
# Epoch 48/50
# 898/898 [==============================] - 54s 60ms/step - loss: 1.6867 - accuracy: 0.8588 - precision: 0.5740 - recall: 0.0447 - auc: 0.7260 - val_loss: 1.6896 - val_accuracy: 0.8592 - val_precision: 0.5396 - val_recall: 0.0988 - val_auc: 0.7279 - lr: 0.0010
# Epoch 49/50
# 898/898 [==============================] - 55s 61ms/step - loss: 1.6839 - accuracy: 0.8588 - precision: 0.5718 - recall: 0.0475 - auc: 0.7277 - val_loss: 1.6601 - val_accuracy: 0.8609 - val_precision: 0.6553 - val_recall: 0.0561 - val_auc: 0.7398 - lr: 0.0010
# Epoch 50/50
# 898/898 [==============================] - 54s 60ms/step - loss: 1.6823 - accuracy: 0.8585 - precision: 0.5575 - recall: 0.0461 - auc: 0.7290 - val_loss: 1.6588 - val_accuracy: 0.8598 - val_precision: 0.7230 - val_recall: 0.0298 - val_auc: 0.7411 - lr: 0.0010

# %% [markdown]
# #Save model

# %%
model.save_weights('/content/drive/My Drive/Colab Notebooks/transfer_model/ResNet_weights-50.h5')

# %% [markdown]
# # Predict model

# %%
import numpy as np
from keras.preprocessing import image
label_dict = {0:'Angry',1:'Disgust',2:'Fear',3:'Happy',4:'Neutral',5:'Sad',6:'Surprise'}

def predict(img_dir):
  img = load_img(img_dir,target_size = (48,48),color_mode = "rgb")
  img = np.array(img)
  img = np.expand_dims(img,axis = 0) # Makes image shape (1,48,48)
  img = img.reshape(1,48,48,3)
  result = model.predict(img)
  result = list(result[0])
  img_index = result.index(max(result))
  return label_dict[img_index]

result = predict("/content/test/happy/PrivateTest_10513598.jpg")
print(result)

# %% [markdown]
# # **Model evaluation:**

# %%
# Using Tensorboard 
# %tensorboard --logdir logs/fit

# %%
# Or using plotting 
# Create plots for accuracy and loss.
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
fig.set_size_inches(12,4)

ax[0].plot(history.history['accuracy'])
ax[0].plot(history.history['val_accuracy'])
ax[0].set_title('Training Accuracy vs Validation Accuracy')
ax[0].set_ylabel('Accuracy')
ax[0].set_xlabel('Epoch')
ax[0].legend(['Train', 'Validation'], loc='upper left')

ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[1].set_title('Training Loss vs Validation Loss')
ax[1].set_ylabel('Loss')
ax[1].set_xlabel('Epoch')
ax[1].legend(['Train', 'Validation'], loc='upper left')

plt.show()

# %%
# Create confusion matrix of our predictions

# compute predictions
predictions = model.predict_generator(generator=val_set)
y_pred = [np.argmax(probas) for probas in predictions]
y_test = val_set.classes
class_names = val_set.class_indices.keys()

# Create function to plot confussion matrix.
def plot_confusion_matrix(cm, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    plt.figure(figsize=(12,6), dpi=120)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')# **Live Class Monitoring System(Face Emotion Recognition)**
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.show()
    
# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, title='Normalized confusion matrix')
plt.show()

# %% [markdown]
# ## Pretrain Model

# %% [markdown]
# Load model:

# %% [markdown]
# loaded_model = load_model("AlexNet_model-100iters.h5")
# loaded_model.load_weights("AlexNet_model_weights-100iters.h5")
