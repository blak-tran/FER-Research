# %% [markdown]
# <a href="https://colab.research.google.com/github/anishjohnson/Face-Emotion-Recognition/blob/main/FER/Colab%20Notebook/Face_Emotion_Recognition_Anish_Johnson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Face Emotion Recognition**

# %% [markdown]
# # **Objective**
# Our objective is to solve the above mentioned challenge by applying deep learning algorithms to live video data inorder to recognize the facial emotions and categorize them accordingly.

# %% [markdown]
# # **Dataset used**
# We have utilized the [FER 2013](https://www.kaggle.com/datasets/msambare/fer2013) dataset provided on Kaggle.<br>
# The data consists of 48x48 pixel grayscale images of faces. The faces have been automatically registered so that the face is more or less centred and occupies about the same amount of space in each image.<br>
#
# The task is to categorize each face based on the emotion shown in the facial expression into one of seven categories (0=Angry, 1=Disgust, 2=Fear, 3=Happy, 4=Sad, 5=Surprise, 6=Neutral). The training set consists of 28,709 examples and the public test set consists of 3,589 examples.

# %%
# !nvidia-smi
# !nvcc -V
# Out:
# Mon Feb 20 00:30:37 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 528.33       Driver Version: 528.33       CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   46C    P8     9W /  80W |      0MiB /  6144MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Fri_Jan__6_19:04:39_Pacific_Standard_Time_2023
# Cuda compilation tools, release 12.0, V12.0.140
# Build cuda_12.0.r12.0/compiler.32267302_0

# %% [markdown]
# ### **Let's Begin:**

# %% [markdown]
# # **Data Exploration:**

# %% [markdown]
# **Lets start by importing the required libraries.**

# %%
# Basic python libraries.
import datetime
import numpy as np
import os
import tensorflow as tf
import matplotlib.pyplot as plt
from tqdm import tqdm
from PIL import Image
import itertools

# Get rid of warnings!
import warnings
warnings.filterwarnings('ignore')

# Deep learning libraries.
from sklearn.metrics import confusion_matrix
from tensorflow.keras import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout
from keras.optimizers import SGD

print('Above libraries have been imported.')
# Out:
# Above libraries have been imported.

# %% [markdown]
# **Seperate the Training and Validation Data.**

# %%
# Define the train and validataion data paths.
train_dir = 'Dataset/train'
val_dir = 'Dataset/test'

# %%
# Define the default image size.
img_size = 48

# Define the seven emotions provided in dataset.
emotion_list = ['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral']

# Plot the images with each distinct emotions.
plt.figure(figsize=(18,22))
i = 1
for expression in emotion_list:
    img = load_img((train_dir + '/' + expression +'/'+ os.listdir(train_dir + '/' + expression)[59]))
    plt.subplot(1,7,i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()

# %% [markdown]
# **Have a look at our data.**

# %% [markdown]
# **Perform some Data Augmentation on train and validations sets.**

# %%
def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    # SOURCE: https://jkjung-avt.github.io/keras-image-cropping/
    assert img.shape[2] == 3
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]

# %% [markdown]
# # **Data Preprocessing:**

# %%
# Rescale the data.
'''
Before we proceed we need to rescale our data by multiplying it to 1/255.
This is done so we get target values between 0 and 1.
'''
# Rescale train data.
datagen_train = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

# Rescale validation data.
datagen_val = ImageDataGenerator(rescale = 1./255,
                                 )

print('Above data generator functions have been created.')
# Out:
# Above data generator functions have been created.

# %%
# Perform data augmentation.
'''
Data augmentation is a technique to artificially create new training data from existing training data. 
It helps us to increase the size of the dataset and introduce variability in the dataset.
'''
# Define the default image size.
img_size = 48

# Define batch size.
batch_size = 64

                                         
# Train data
train_set = datagen_train.flow_from_directory(
    directory=train_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)

# Validation data
val_set = datagen_train.flow_from_directory(
    directory=val_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)


print('Train and Validation sets have been created.')
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.
# Train and Validation sets have been created.

# %% [markdown]
# **Now lets create our custom CNN model.**

# %% [markdown]
# # **Build CNN Model:**

# %% [markdown]
# **Before we start building the neural network lets understand some of the terms that we will be using.**
#
# * **Model = sequential** : A Sequential model is appropriate for a plain stack of layers where each layer has exactly one input tensor and one output tensor.
#
# * **Padding** = The padding parameter of the Keras Conv2D class can take one of two values: 'valid' or 'same'. Setting the value to “valid” parameter means that the input volume is not zero-padded and the spatial dimensions are allowed to reduce via the natural application of convolution.
#
# * **Activation** = relu :The rectified linear activation function or ReLU for short is a piecewise linear function that will output the input directly if it is positive, otherwise, it will output zero. It has become the default activation function for many types of neural networks because a model that uses it is easier to train and often achieves better performance.
#
# * **Maxpooling** = Maximum pooling, or max pooling, is a pooling operation that calculates the maximum, or largest, value in each patch of each feature map. The results are down sampled or pooled feature maps that highlight the most present feature in the patch, not the average presence of the feature in the case of average pooling.
#
# * **Batch normalization** = Batch normalization is a technique for training very deep neural networks that standardizes the inputs to a layer for each mini-batch. This has the effect of stabilizing the learning process and dramatically reducing the number of training epochs required to train deep networks.
#
# * **Dropout** = Dropout is a technique used to prevent a model from overfitting. Dropout works by randomly setting the outgoing edges of hidden units (neurons that make up hidden layers) to 0 at each update of the training phase.
#
# * **Adam** = Adaptive Moment Estimation is an algorithm for optimization technique for gradient descent. The method is really efficient when working with large problem involving a lot of data or parameters. It requires less memory and is efficient. Intuitively, it is a combination of the ‘gradient descent with momentum’ algorithm and the ‘RMSP’ algorithm. It uses the squared gradients to scale the learning rate like RMSprop and it takes advantage of momentum by using moving average of the gradient instead of gradient itself like SGD with momentum.

# %%
# AlexNet model

class AlexNet(Sequential):
  def __init__(self, input_shape, num_classes):
    super().__init__()
    self.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    self.add(MaxPooling2D((2, 2)))
    self.add(Conv2D(64, (3, 3), activation='relu'))
    self.add(MaxPooling2D((2, 2)))
    self.add(Conv2D(128, (3, 3), activation='relu'))
    self.add(MaxPooling2D((2, 2)))
    self.add(Flatten())
    self.add(Dense(128, activation='relu'))
    self.add(Dropout(0.5))
    self.add(Dense(num_classes, activation='softmax'))

    opt = SGD(lr=0.01)
    self.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# %%
model = AlexNet((48,48,3),7)

epochs = 150
steps_per_epoch = train_set.n//train_set.batch_size
validation_steps = val_set.n//val_set.batch_size

history = model.fit(train_set,
                              steps_per_epoch=steps_per_epoch,
                              epochs=epochs,
                              batch_size = 32,
                              validation_data=val_set,
                              validation_steps=validation_steps)
# Out:
# Epoch 1/150
# 448/448 [==============================] - 29s 59ms/step - loss: 1.8187 - accuracy: 0.2508 - val_loss: 1.8115 - val_accuracy: 0.2473
# Epoch 2/150
# 448/448 [==============================] - 32s 70ms/step - loss: 1.8027 - accuracy: 0.2536 - val_loss: 1.7961 - val_accuracy: 0.2514
# Epoch 3/150
# 448/448 [==============================] - 30s 67ms/step - loss: 1.7874 - accuracy: 0.2588 - val_loss: 1.7817 - val_accuracy: 0.2829
# Epoch 4/150
# 448/448 [==============================] - 29s 65ms/step - loss: 1.7637 - accuracy: 0.2754 - val_loss: 1.7713 - val_accuracy: 0.2750
# Epoch 5/150
# 448/448 [==============================] - 29s 64ms/step - loss: 1.7287 - accuracy: 0.3080 - val_loss: 1.7118 - val_accuracy: 0.3138
# Epoch 6/150
# 448/448 [==============================] - 29s 64ms/step - loss: 1.6901 - accuracy: 0.3350 - val_loss: 1.6768 - val_accuracy: 0.3525
# Epoch 7/150
# 448/448 [==============================] - 28s 62ms/step - loss: 1.6621 - accuracy: 0.3499 - val_loss: 1.6593 - val_accuracy: 0.3555
# Epoch 8/150
# 448/448 [==============================] - 28s 62ms/step - loss: 1.
# Epoch 29/150
# 448/448 [==============================] - 30s 67ms/step - loss: 1.3552 - accuracy: 0.4852 - val_loss: 1.3932 - val_accuracy: 0.4731
# Epoch 30/150
# 448/448 [==============================] - 30s 66ms/step - loss: 1.3448 - accuracy: 0.4907 - val_loss: 1.3707 - val_accuracy: 0.4837
# Epoch 31/150
# 448/448 [==============================] - 30s 68ms/step - loss: 1.3393 - accuracy: 0.4915 - val_loss: 1.3659 - val_accuracy: 0.4753
# Epoch 32/150
# 448/448 [==============================] - 35s 77ms/step - loss: 1.3282 - accuracy: 0.4938 - val_loss: 1.3596 - val_accuracy: 0.4847
# Epoch 33/150
# 448/448 [==============================] - 35s 79ms/step - loss: 1.3127 - accuracy: 0.5006 - val_loss: 1.3575 - val_accuracy: 0.4965
# Epoch 34/150
# 448/448 [==============================] - 35s 78ms/step - loss: 1.3041 - accuracy: 0.5075 - val_loss: 1.3474 - val_accuracy: 0.4904
# Epoch 35/150
# 448/448 [==============================] - 35s 78ms/step - loss: 1.2973 - accuracy: 0.5060 - val_loss: 1.3447 - val_accuracy: 0.4909
# Epoch 36/150
# 448/448 [==============================] - 34s 76ms/step - loss: 1.2890 - accuracy: 0.5137 - val_loss: 1.3339 - val_accuracy: 0.4919
# Epoch 37/150
# 448/448 [==============================] - 34s 76ms/step - loss: 1.2769 - accuracy: 0.5196 - val_loss: 1.3255 - val_accuracy: 0.4968
# Epoch 38/150
# 448/448 [==============================] - 34s 76ms/step - loss: 1.2752 - accuracy: 0.5160 - val_loss: 1.3188 - val_accuracy: 0.4985
# Epoch 39/150
# 448/448 [==============================] - 34s 76ms/step - loss: 1.2622 - accuracy: 0.5216 - val_loss: 1.3124 - val_accuracy: 0.4971
# Epoch 40/150
# 448/448 [==============================] - 34s 76ms/step - loss: 1.2560 - accuracy: 0.5257 - val_loss: 1.3352 - val_accuracy: 0.4987
# Epoch 41/150
# 448/448 [==============================] - 34s 77ms/step - loss: 1.2484 - accuracy: 0.5294 - val_loss: 1.3063 - val_accuracy: 0.5123
# Epoch 42/150
# 448/448 [==============================] - 35s 79ms/step - loss: 1.2405 - accuracy: 0.5307 - val_loss: 1.3048 - val_accuracy: 0.5018
# Epoch 43/150
# 448/448 [==============================] - 35s 77ms/step - loss: 1.2294 - accuracy: 0.5351 - val_loss: 1.3161 - val_accuracy: 0.4962
# Epoch 44/150
# 448/448 [==============================] - 35s 79ms/step - loss: 1.2247 - accuracy: 0.5378 - val_loss: 1.2874 - val_accuracy: 0.5114
# Epoch 45/150
# 448/448 [==============================] - 35s 79ms/step - loss: 1.2168 - accuracy: 0.5431 - val_loss: 1.3063 - val_accuracy: 0.5082
# Epoch 46/150
# 448/448 [==============================] - 35s 78ms/step - loss: 1.2084 - accuracy: 0.5437 - val_loss: 1.2869 - val_accuracy: 0.5109
# Epoch 47/150
# 448/448 [==============================] - 34s 77ms/step - loss: 1.1968 - accuracy: 0.5474 - val_loss: 1.2927 - val_accuracy: 0.5160
# Epoch 48/150
# 448/448 [==============================] - 35s 77ms/step - loss: 1.1918 - accuracy: 0.5502 - val_loss: 1.2865 - val_accuracy: 0.5109
# Epoch 49/150
# 448/448 [==============================] - 34s 76ms/step - loss: 1.1925 - accuracy: 0.5496 - val_loss: 1.2759 - val_accuracy: 0.5138
# Epoch 50/150
# 448/448 [==============================] - 34s 76ms/step - loss: 1.1826 - accuracy: 0.5544 - val_loss: 1.2868 - val_accuracy: 0.5144
# Epoch 51/150
# 448/448 [==============================] - 35s 78ms/step - loss: 1.1748 - accuracy: 0.5585 - val_loss: 1.2853 - val_accuracy: 0.5159
# Epoch 52/150
# 448/448 [==============================] - 35s 77ms/step - loss: 1.1624 - accuracy: 0.5640 - val_loss: 1.2668 - val_accuracy: 0.5153
# Epoch 53/150
# 448/448 [==============================] - 35s 77ms/step - loss: 1.1629 - accuracy: 0.5615 - val_loss: 1.2550 - val_accuracy: 0.5303
# Epoch 54/150
# 448/448 [==============================] - 34s 76ms/step - loss: 1.1532 - accuracy: 0.5653 - val_loss: 1.2621 - val_accuracy: 0.5198
# Epoch 55/150
# 448/448 [==============================] - 35s 78ms/step - loss: 1.1508 - accuracy: 0.5669 - val_loss: 1.2540 - val_accuracy: 0.5244
# Epoch 56/150
# 448/448 [==============================] - 35s 79ms/step - loss: 1.1415 - accuracy: 0.5700 - val_loss: 1.2426 - val_accuracy: 0.5279
# Epoch 57/150
# 448/448 [==============================] - 34s 76ms/step - loss: 1.1331 - accuracy: 0.5747 - val_loss: 1.2452 - val_accuracy: 0.5294
# Epoch 58/150
# 448/448 [==============================] - 34s 76ms/step - loss: 1.1262 - accuracy: 0.5798 - val_loss: 1.2611 - val_accuracy: 0.5251
# Epoch 59/150
# 448/448 [==============================] - 34s 75ms/step - loss: 1.1206 - accuracy: 0.5761 - val_loss: 1.2570 - val_accuracy: 0.5276
# Epoch 60/150
# 448/448 [==============================] - 34s 76ms/step - loss: 1.1101 - accuracy: 0.5854 - val_loss: 1.2657 - val_accuracy: 0.5253
# Epoch 61/150
# 448/448 [==============================] - 34s 76ms/step - loss: 1.1055 - accuracy: 0.5858 - val_loss: 1.2578 - val_accuracy: 0.5377
# Epoch 62/150
# 448/448 [==============================] - 34s 75ms/step - loss: 1.1000 - accuracy: 0.5857 - val_loss: 1.2328 - val_accuracy: 0.5421
# Epoch 63/150
# 448/448 [==============================] - 33s 74ms/step - loss: 1.1015 - accuracy: 0.5877 - val_loss: 1.2478 - val_accuracy: 0.5248
# Epoch 64/150
# 448/448 [==============================] - 34s 76ms/step - loss: 1.0929 - accuracy: 0.5901 - val_loss: 1.2434 - val_accuracy: 0.5381
# Epoch 65/150
# 448/448 [==============================] - 33s 74ms/step - loss: 1.0827 - accuracy: 0.5947 - val_loss: 1.2286 - val_accuracy: 0.5466
# Epoch 66/150
# 448/448 [==============================] - 33s 74ms/step - loss: 1.0798 - accuracy: 0.5975 - val_loss: 1.2363 - val_accuracy: 0.5427
# Epoch 67/150
# 448/448 [==============================] - 34s 76ms/step - loss: 1.0752 - accuracy: 0.5960 - val_loss: 1.2262 - val_accuracy: 0.5462
# Epoch 68/150
# 448/448 [==============================] - 34s 75ms/step - loss: 1.0598 - accuracy: 0.6033 - val_loss: 1.2312 - val_accuracy: 0.5430
# Epoch 69/150
# 448/448 [==============================] - 34s 75ms/step - loss: 1.0605 - accuracy: 0.6035 - val_loss: 1.2335 - val_accuracy: 0.5432
# Epoch 70/150
# 448/448 [==============================] - 35s 78ms/step - loss: 1.0592 - accuracy: 0.6023 - val_loss: 1.2329 - val_accuracy: 0.5469
# Epoch 71/150
# 448/448 [==============================] - 33s 74ms/step - loss: 1.0484 - accuracy: 0.6073 - val_loss: 1.2203 - val_accuracy: 0.5428
# Epoch 72/150
# 448/448 [==============================] - 34s 76ms/step - loss: 1.0418 - accuracy: 0.6122 - val_loss: 1.2338 - val_accuracy: 0.5405
# Epoch 73/150
# 448/448 [==============================] - 33s 75ms/step - loss: 1.0373 - accuracy: 0.6110 - val_loss: 1.2190 - val_accuracy: 0.5472
# Epoch 74/150
# 448/448 [==============================] - 33s 74ms/step - loss: 1.0325 - accuracy: 0.6164 - val_loss: 1.2142 - val_accuracy: 0.5462
# Epoch 75/150
# 448/448 [==============================] - 33s 74ms/step - loss: 1.0293 - accuracy: 0.6135 - val_loss: 1.2328 - val_accuracy: 0.5444
# Epoch 76/150
# 448/448 [==============================] - 33s 75ms/step - loss: 1.0185 - accuracy: 0.6191 - val_loss: 1.2353 - val_accuracy: 0.5372
# Epoch 77/150
# 448/448 [==============================] - 33s 74ms/step - loss: 1.0178 - accuracy: 0.6228 - val_loss: 1.2281 - val_accuracy: 0.5484
# Epoch 78/150
# 448/448 [==============================] - 33s 74ms/step - loss: 1.0131 - accuracy: 0.6212 - val_loss: 1.2270 - val_accuracy: 0.5491
# Epoch 79/150
# 448/448 [==============================] - 33s 73ms/step - loss: 1.0002 - accuracy: 0.6274 - val_loss: 1.2441 - val_accuracy: 0.5446
# Epoch 80/150
# 448/448 [==============================] - 33s 74ms/step - loss: 1.0023 - accuracy: 0.6275 - val_loss: 1.2406 - val_accuracy: 0.5448
# Epoch 81/150
# 448/448 [==============================] - 33s 74ms/step - loss: 0.9919 - accuracy: 0.6315 - val_loss: 1.2683 - val_accuracy: 0.5391
# Epoch 82/150
# 448/448 [==============================] - 33s 74ms/step - loss: 0.9882 - accuracy: 0.6315 - val_loss: 1.2203 - val_accuracy: 0.5465
# Epoch 83/150
# 448/448 [==============================] - 32s 72ms/step - loss: 0.9835 - accuracy: 0.6339 - val_loss: 1.2344 - val_accuracy: 0.5437
# Epoch 84/150
# 448/448 [==============================] - 32s 71ms/step - loss: 0.9769 - accuracy: 0.6368 - val_loss: 1.2186 - val_accuracy: 0.5586
# Epoch 85/150
# 448/448 [==============================] - 32s 71ms/step - loss: 0.9793 - accuracy: 0.6357 - val_loss: 1.2202 - val_accuracy: 0.5477
# Epoch 86/150
# 448/448 [==============================] - 35s 77ms/step - loss: 0.9658 - accuracy: 0.6398 - val_loss: 1.2153 - val_accuracy: 0.5525
# Epoch 87/150
# 448/448 [==============================] - 33s 74ms/step - loss: 0.9628 - accuracy: 0.6440 - val_loss: 1.2193 - val_accuracy: 0.5565
# Epoch 88/150
# 448/448 [==============================] - 36s 80ms/step - loss: 0.9545 - accuracy: 0.6463 - val_loss: 1.2459 - val_accuracy: 0.5511
# Epoch 89/150
# 448/448 [==============================] - 36s 80ms/step - loss: 0.9541 - accuracy: 0.6422 - val_loss: 1.2307 - val_accuracy: 0.5495
# Epoch 90/150
# 448/448 [==============================] - 39s 88ms/step - loss: 0.9469 - accuracy: 0.6484 - val_loss: 1.2358 - val_accuracy: 0.5522
# Epoch 91/150
# 448/448 [==============================] - 39s 86ms/step - loss: 0.9397 - accuracy: 0.6533 - val_loss: 1.2570 - val_accuracy: 0.5534
# Epoch 92/150
# 448/448 [==============================] - 38s 86ms/step - loss: 0.9414 - accuracy: 0.6504 - val_loss: 1.2362 - val_accuracy: 0.5598
# Epoch 93/150
# 448/448 [==============================] - 38s 85ms/step - loss: 0.9364 - accuracy: 0.6511 - val_loss: 1.2317 - val_accuracy: 0.5573
# Epoch 94/150
# 448/448 [==============================] - 38s 84ms/step - loss: 0.9307 - accuracy: 0.6544 - val_loss: 1.2798 - val_accuracy: 0.5307
# Epoch 95/150
# 448/448 [==============================] - 38s 85ms/step - loss: 0.9275 - accuracy: 0.6592 - val_loss: 1.2423 - val_accuracy: 0.5582
# Epoch 96/150
# 448/448 [==============================] - 38s 84ms/step - loss: 0.9174 - accuracy: 0.6615 - val_loss: 1.2394 - val_accuracy: 0.5520
# Epoch 97/150
# 448/448 [==============================] - 38s 85ms/step - loss: 0
# Epoch 137/150
# 448/448 [==============================] - 41s 92ms/step - loss: 0.7312 - accuracy: 0.7297 - val_loss: 1.3517 - val_accuracy: 0.5543
# Epoch 138/150
# 448/448 [==============================] - 41s 92ms/step - loss: 0.7212 - accuracy: 0.7353 - val_loss: 1.4189 - val_accuracy: 0.5410
# Epoch 139/150
# 448/448 [==============================] - 39s 87ms/step - loss: 0.7186 - accuracy: 0.7370 - val_loss: 1.3672 - val_accuracy: 0.5653
# Epoch 140/150
# 448/448 [==============================] - 30s 67ms/step - loss: 0.7187 - accuracy: 0.7362 - val_loss: 1.3419 - val_accuracy: 0.5557
# Epoch 141/150
# 448/448 [==============================] - 27s 61ms/step - loss: 0.7087 - accuracy: 0.7429 - val_loss: 1.3384 - val_accuracy: 0.5480
# Epoch 142/150
# 448/448 [==============================] - 28s 62ms/step - loss: 0.7090 - accuracy: 0.7415 - val_loss: 1.3427 - val_accuracy: 0.5589
# Epoch 143/150
# 448/448 [==============================] - 28s 61ms/step - loss: 0.7117 - accuracy: 0.7415 - val_loss: 1.3590 - val_accuracy: 0.5490
# Epoch 144/150
# 448/448 [==============================] - 28s 63ms/step - loss: 0.6958 - accuracy: 0.7465 - val_loss: 1.3841 - val_accuracy: 0.5621
# Epoch 145/150
# 448/448 [==============================] - 28s 62ms/step - loss: 0.6976 - accuracy: 0.7460 - val_loss: 1.3744 - val_accuracy: 0.5668
# Epoch 146/150
# 448/448 [==============================] - 32s 70ms/step - loss: 0.6867 - accuracy: 0.7486 - val_loss: 1.3375 - val_accuracy: 0.5614
# Epoch 147/150
# 448/448 [==============================] - 30s 68ms/step - loss: 0.6846 - accuracy: 0.7501 - val_loss: 1.3453 - val_accuracy: 0.5653
# Epoch 148/150
# 448/448 [==============================] - 31s 69ms/step - loss: 0.6778 - accuracy: 0.7514 - val_loss: 1.4249 - val_accuracy: 0.5502
# Epoch 149/150
# 448/448 [==============================] - 31s 68ms/step - loss: 0.6831 - accuracy: 0.7508 - val_loss: 1.3868 - val_accuracy: 0.5573
# Epoch 150/150
# 448/448 [==============================] - 30s 66ms/step - loss: 0.6740 - accuracy: 0.7527 - val_loss: 1.4119 - val_accuracy: 0.5561

# %% [markdown]
# #Save model

# %%
model_weights_dir = "AlexNet_weighs_iters150.h5"

# %%
# Save the whole model
model.save_weights(model_weights_dir)

# %% [markdown]
# # **Model evaluation:**

# %%
# Using Tensorboard 
# %tensorboard --logdir logs/fit

# %%
# Or using plotting 
# Create plots for accuracy and loss.
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
fig.set_size_inches(12,4)

ax[0].plot(history.history['accuracy'])
ax[0].plot(history.history['val_accuracy'])
ax[0].set_title('Training Accuracy vs Validation Accuracy')
ax[0].set_ylabel('Accuracy')
ax[0].set_xlabel('Epoch')
ax[0].legend(['Train', 'Validation'], loc='upper left')

ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[1].set_title('Training Loss vs Validation Loss')
ax[1].set_ylabel('Loss')
ax[1].set_xlabel('Epoch')
ax[1].legend(['Train', 'Validation'], loc='upper left')

plt.show()

# %%
# Create confusion matrix of our predictions

# compute predictions
predictions = model.predict_generator(generator=val_set)
y_pred = [np.argmax(probas) for probas in predictions]
y_test = val_set.classes
class_names = val_set.class_indices.keys()

# Create function to plot confussion matrix.
def plot_confusion_matrix(cm, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    plt.figure(figsize=(12,6), dpi=120)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')# **Live Class Monitoring System(Face Emotion Recognition)**
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.show()
    
# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, title='Normalized confusion matrix')
plt.show()

# %% [markdown]
# ## Pretrain Model

# %% [markdown]
# Load model:

# %% [markdown]
# loaded_model = load_model("AlexNet_model-100iters.h5")
# loaded_model.load_weights("AlexNet_model_weights-100iters.h5")
