# %% [markdown]
# <a href="https://colab.research.google.com/github/anishjohnson/Face-Emotion-Recognition/blob/main/FER/Colab%20Notebook/Face_Emotion_Recognition_Anish_Johnson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Face Emotion Recognition**

# %% [markdown]
# # **Objective**
# Our objective is to solve the above mentioned challenge by applying deep learning algorithms to live video data inorder to recognize the facial emotions and categorize them accordingly.

# %% [markdown]
# # **Dataset used**
# We have utilized the [FER 2013](https://www.kaggle.com/datasets/msambare/fer2013) dataset provided on Kaggle.<br>
# The data consists of 48x48 pixel grayscale images of faces. The faces have been automatically registered so that the face is more or less centred and occupies about the same amount of space in each image.<br>
#
# The task is to categorize each face based on the emotion shown in the facial expression into one of seven categories (0=Angry, 1=Disgust, 2=Fear, 3=Happy, 4=Sad, 5=Surprise, 6=Neutral). The training set consists of 28,709 examples and the public test set consists of 3,589 examples.

# %%
# !nvidia-smi
# !nvcc -V
# Out:
# Tue Feb 21 21:58:55 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 528.33       Driver Version: 528.33       CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   48C    P8     9W /  80W |      0MiB /  6144MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Fri_Jan__6_19:04:39_Pacific_Standard_Time_2023
# Cuda compilation tools, release 12.0, V12.0.140
# Build cuda_12.0.r12.0/compiler.32267302_0

# %% [markdown]
# ### **Let's Begin:**

# %% [markdown]
# # **Data Exploration:**

# %% [markdown]
# **Lets start by importing the required libraries.**

# %%
# Basic python libraries.
import datetime
import numpy as np
import os
import tensorflow as tf
import matplotlib.pyplot as plt
from tqdm import tqdm
from PIL import Image
import itertools

# Get rid of warnings!
import warnings
warnings.filterwarnings('ignore')

# Deep learning libraries.
from sklearn.metrics import confusion_matrix
from tensorflow.keras import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout
from keras.optimizers import SGD

print('Above libraries have been imported.')
# Out:
# Above libraries have been imported.

# %% [markdown]
# **Seperate the Training and Validation Data.**

# %%
tf.__version__
# Out:
# '2.11.0'

# %%
# Define the train and validataion data paths.
train_dir = 'Dataset/train'
val_dir = 'Dataset/test'

# %%
# Define the default image size.
img_size = 48

# Define the seven emotions provided in dataset.
emotion_list = ['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral']

# Plot the images with each distinct emotions.
plt.figure(figsize=(18,22))
i = 1
for expression in emotion_list:
    img = load_img((train_dir + '/' + expression +'/'+ os.listdir(train_dir + '/' + expression)[59]))
    plt.subplot(1,7,i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()

# %% [markdown]
# **Have a look at our data.**

# %% [markdown]
# **Perform some Data Augmentation on train and validations sets.**

# %% [markdown]
# # **Data Preprocessing:**

# %%
# Rescale the data.
'''
Before we proceed we need to rescale our data by multiplying it to 1/255.
This is done so we get target values between 0 and 1.
'''
# Rescale train data.
datagen_train = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

# Rescale validation data.
datagen_val = ImageDataGenerator(rescale = 1./255,
                                 )

print('Above data generator functions have been created.')
# Out:
# Above data generator functions have been created.

# %%
# Perform data

'''
Data augmentation is a technique to artificially create new training data from existing training data. 
It helps us to increase the size of the dataset and introduce variability in the dataset.
'''
# Define the default image size.
img_size = 48

# Define batch size.
batch_size = 32

                                         
# Train data
train_set = datagen_train.flow_from_directory(
    directory=train_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    color_mode = 'rgb',
    class_mode='categorical',
    shuffle=True
)

# Validation data
val_set = datagen_train.flow_from_directory(
    directory=val_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    color_mode = 'rgb',
    class_mode='categorical',
    shuffle=False
)


print('Train and Validation sets have been created.')
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.
# Train and Validation sets have been created.

# %% [markdown]
# **Now lets create our custom CNN model.**

# %% [markdown]
# # **Build CNN Model:**

# %% [markdown]
# **Before we start building the neural network lets understand some of the terms that we will be using.**
#
# * **Model = sequential** : A Sequential model is appropriate for a plain stack of layers where each layer has exactly one input tensor and one output tensor.
#
# * **Padding** = The padding parameter of the Keras Conv2D class can take one of two values: 'valid' or 'same'. Setting the value to “valid” parameter means that the input volume is not zero-padded and the spatial dimensions are allowed to reduce via the natural application of convolution.
#
# * **Activation** = relu :The rectified linear activation function or ReLU for short is a piecewise linear function that will output the input directly if it is positive, otherwise, it will output zero. It has become the default activation function for many types of neural networks because a model that uses it is easier to train and often achieves better performance.
#
# * **Maxpooling** = Maximum pooling, or max pooling, is a pooling operation that calculates the maximum, or largest, value in each patch of each feature map. The results are down sampled or pooled feature maps that highlight the most present feature in the patch, not the average presence of the feature in the case of average pooling.
#
# * **Batch normalization** = Batch normalization is a technique for training very deep neural networks that standardizes the inputs to a layer for each mini-batch. This has the effect of stabilizing the learning process and dramatically reducing the number of training epochs required to train deep networks.
#
# * **Dropout** = Dropout is a technique used to prevent a model from overfitting. Dropout works by randomly setting the outgoing edges of hidden units (neurons that make up hidden layers) to 0 at each update of the training phase.
#
# * **Adam** = Adaptive Moment Estimation is an algorithm for optimization technique for gradient descent. The method is really efficient when working with large problem involving a lot of data or parameters. It requires less memory and is efficient. Intuitively, it is a combination of the ‘gradient descent with momentum’ algorithm and the ‘RMSP’ algorithm. It uses the squared gradients to scale the learning rate like RMSprop and it takes advantage of momentum by using moving average of the gradient instead of gradient itself like SGD with momentum.

# %%
class VGGNet(Sequential):
  def __init__(self, input_shape, num_classes):
    super().__init__()

    self.add(Conv2D(64, (3, 3), activation='relu', padding='same', input_shape=(48, 48, 3)))
    self.add(MaxPooling2D(pool_size=(2, 2)))

    self.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
    self.add(MaxPooling2D(pool_size=(2, 2)))

    self.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
    self.add(MaxPooling2D(pool_size=(2, 2)))

    self.add(Flatten())
    self.add(Dense(4096, activation='relu'))
    self.add(Dropout(0.5))
    self.add(Dense(1000, activation='relu'))
    self.add(Dropout(0.5))
    self.add(Dense(num_classes, activation='softmax'))
    opt = SGD(lr=0.01)
    self.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    self.summary()

# %%
model = VGGNet((48,48,3),7)

epochs = 100
steps_per_epoch = train_set.n//train_set.batch_size
validation_steps = val_set.n//val_set.batch_size

history = model.fit(train_set,
                              steps_per_epoch=steps_per_epoch,
                              epochs=epochs,
                              batch_size = 32,
                              validation_data=val_set,
                              validation_steps=validation_steps)
# Out:
# Model: "vgg_net"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 64)        1792
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 64)        36928
#
#  max_pooling2d (MaxPooling2D  (None, 24, 24, 64)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 24, 24, 128)       73856
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 256)       295168
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 4096)              37752832
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 1000)              4097000
#
#  dropout_2 (Dropout)         (None, 1000)              0
#
#  dense_3 (Dense)             (None, 7)                 7007
#
# =================================================================
# Total params: 59,045,895
# Trainable params: 59,045,895
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 897/897 [==============================] - 35s 36ms/step - loss: 1.8286 - accuracy: 0.2444 - val_loss: 1.8153 - val_accuracy: 0.2475
# Epoch 2/100
# 897/897 [==============================] - 32s 35ms/step - loss: 1.8122 - accuracy: 0.2507 - val_loss: 1.8058 - val_accuracy: 0.2475
# Epoch 3/100
# 897/897 [==============================] - 32s 36ms/step - loss: 1.8021 - accuracy: 0.2506 - val_loss: 1.7827 - val_accuracy: 0.2517
# Epoch 4/100
# 897/897 [==============================] - 32s 36ms/step - loss: 1.7844 - accuracy: 0.2565 - val_loss: 1.7615 - val_accuracy: 0.2716
# Epoch 5/100
# 897/897 [==============================] - 33s 36ms/step - loss: 1.7686 - accuracy: 0.2658 - val_loss: 1.7390 - val_accuracy: 0.3018
# Epoch 6/100
# 897/897 [==============================] - 32s 36ms/step - loss: 1.7430 - accuracy: 0.2921 - val_loss: 1.6995 - val_accuracy: 0.3274
# Epoch 7/100
# 897/897 [==============================] - 33s 37ms/step - loss: 1.7027 - accuracy: 0.3236 - val_loss: 1.6492 - val_accuracy: 0.3585
# Epoch 8/100
# 897/897 [==============================] - 33s 36ms/step - loss: 1.6653 - accuracy: 0.3416 - val_loss: 1.6476 - val_accuracy: 0.3617
# Epoch 9/100
# 897/897 [==============================] - 33s 36ms/step - loss: 1.6342 - accuracy: 0.3576 - val_loss: 1.5928 - val_accuracy: 0.3835
# Epoch 10/100
# 897/897 [==============================] - 33s 37ms/step - loss: 1.6036 - accuracy: 0.3724 - val_loss: 1.5518 - val_accuracy: 0.3976
# Epoch 11/100
# 897/897 [==============================] - 35s 39ms/step - loss: 1.5698 - accuracy: 0.3896 - val_loss: 1.5330 - val_accuracy: 0.4127
# Epoch 12/100
# 897/897 [==============================] - 33s 36ms/step - loss: 1.5393 - accuracy: 0.4030 - val_loss: 1.5093 - val_accuracy: 0.4174
# Epoch 13/100
# 897/897 [==============================] - 33s 37ms/step - loss: 1.5076 - accuracy: 0.4153 - val_loss: 1.4586 - val_accuracy: 0.4417
# Epoch 14/100
# 897/897 [==============================] - 33s 36ms/step - loss: 1.4777 - accuracy: 0.4290 - val_loss: 1.4290 - val_accuracy: 0.4505
# Epoch 15/100
# 897/897 [==============================] - 33s 36ms/step - loss: 1.4446 - accuracy: 0.4439 - val_loss: 1.3931 - val_accuracy: 0.4647
# Epoch 16/100
# 897/897 [==============================] - 33s 36ms/step - loss: 1.4171 - accuracy: 0.4512 - val_loss: 1.3668 - val_accuracy: 0.4743
# Epoch 17/100
# 897/897 [==============================] - 33s 37ms/step - loss: 1.3884 - accuracy: 0.4688 - val_loss: 1.3579 - val_accuracy: 0.4738
# Epoch 18/100
# 897/897 [==============================] - 33s 37ms/step - loss: 1.3505 - accuracy: 0.4824 - val_loss: 1.3138 - val_accuracy: 0.4944
# Epoch 19/100
# 897/897 [==============================] - 34s 38ms/step - loss: 1.3256 - accuracy: 0.4962 - val_loss: 1.2851 - val_accuracy: 0.5067
# Epoch 20/100
# 897/897 [==============================] - 33s 36ms/step - loss: 1.3007 - accuracy: 0.4988 - val_loss: 1.2736 - val_accuracy: 0.5098
# Epoch 21/100
# 897/897 [==============================] - 34s 38ms/step - loss: 1.2729 - accuracy: 0.5184 - val_loss: 1.2486 - val_accuracy: 0.5215
# Epoch 22/100
# 897/897 [==============================] - 33s 37ms/step - loss: 1.2495 - accuracy: 0.5226 - val_loss: 1.2340 - val_accuracy: 0.5292
# Epoch 23/100
# 897/897 [==============================] - 29s 32ms/step - loss: 1.2296 - accuracy: 0.5344 - val_loss: 1.2068 - val_accuracy: 0.5349
# Epoch 24/100
# 897/897 [==============================] - 30s 33ms/step - loss: 1.2081 - accuracy: 0.5413 - val_loss: 1.1806 - val_accuracy: 0.5452
# Epoch 25/100
# 897/897 [==============================] - 29s 32ms/step - loss: 1.1893 - accuracy: 0.5500 - val_loss: 1.1855 - val_accuracy: 0.5492
# Epoch 26/100
# 897/897 [==============================] - 29s 33ms/step - loss: 1.1719 - accuracy: 0.5556 - val_loss: 1.1689 - val_accuracy: 0.5515
# Epoch 27/100
# 897/897 [==============================] - 29s 32ms/step - loss: 1.1516 - accuracy: 0.5619 - val_loss: 1.1592 - val_accuracy: 0.5578
# Epoch 28/100
# 897/897 [==============================] - 29s 33ms/step - loss: 1.1368 - accuracy: 0.5724 - val_loss: 1.1425 - val_accuracy: 0.5650
# Epoch 29/100
# 897/897 [==============================] - 29s 32ms/step - loss: 1.1214 - accuracy: 0.5754 - val_loss: 1.1506 - val_accuracy: 0.5649
# Epoch 30/100
# 897/897 [==============================] - 29s 33ms/step - loss: 1.1130 - accuracy: 0.5804 - val_loss: 1.1305 - val_accuracy: 0.5738
# Epoch 31/100
# 897/897 [==============================] - 34s 37ms/step - loss: 1.0917 - accuracy: 0.5917 - val_loss: 1.1321 - val_accuracy: 0.5801
# Epoch 32/100
# 897/897 [==============================] - 29s 33ms/step - loss: 1.0804 - accuracy: 0.5916 - val_loss: 1.1345 - val_accuracy: 0.5763
# Epoch 33/100
# 897/897 [==============================] - 29s 33ms/step - loss: 1.0659 - accuracy: 0.5992 - val_loss: 1.1042 - val_accuracy: 0.5812
# Epoch 34/100
# 897/897 [==============================] - 29s 33ms/step - loss: 1.0497 - accuracy: 0.6027 - val_loss: 1.0927 - val_accuracy: 0.5862
# Epoch 35/100
# 897/897 [==============================] - 29s 32ms/step - loss: 1.0399 - accuracy: 0.6101 - val_loss: 1.0958 - val_accuracy: 0.5865
# Epoch 36/100
# 897/897 [==============================] - 29s 33ms/step - loss: 1.0209 - accuracy: 0.6160 - val_loss: 1.0834 - val_accuracy: 0.5932
# Epoch 37/100
# 897/897 [==============================] - 29s 33ms/step - loss: 1.0054 - accuracy: 0.6243 - val_loss: 1.0857 - val_accuracy: 0.5946
# Epoch 38/100
# 897/897 [==============================] - 29s 33ms/step - loss: 0.9935 - accuracy: 0.6266 - val_loss: 1.0879 - val_accuracy: 0.5857
# Epoch 39/100
# 897/897 [==============================] - 30s 33ms/step - loss: 0.9820 - accuracy: 0.6319 - val_loss: 1.0740 - val_accuracy: 0.5953
# Epoch 40/100
# 897/897 [==============================] - 30s 33ms/step - loss: 0.9706 - accuracy: 0.6379 - val_loss: 1.0835 - val_accuracy: 0.5938
# Epoch 41/100
# 897/897 [==============================] - 30s 33ms/step - loss: 0.9533 - accuracy: 0.6447 - val_loss: 1.0743 - val_accuracy: 0.6003
# Epoch 42/100
# 897/897 [==============================] - 30s 33ms/step - loss: 0.9434 - accuracy: 0.6447 - val_loss: 1.0556 - val_accuracy: 0.6097
# Epoch 43/100
# 897/897 [==============================] - 30s 33ms/step - loss: 0.9318 - accuracy: 0.6501 - val_loss: 1.0849 - val_accuracy: 0.5939
# Epoch 44/100
# 897/897 [==============================] - 29s 33ms/step - loss: 0.9185 - accuracy: 0.6586 - val_loss: 1.0547 - val_accuracy: 0.6097
# Epoch 45/100
# 897/897 [==============================] - 29s 32ms/step - loss: 0.9074 - accuracy: 0.6584 - val_loss: 1.0663 - val_accuracy: 0.6073
# Epoch 46/100
# 897/897 [==============================] - 29s 33ms/step - loss: 0.8967 - accuracy: 0.6660 - val_loss: 1.0357 - val_accuracy: 0.6186
# Epoch 47/100
# 897/897 [==============================] - 29s 33ms/step - loss: 0.8794 - accuracy: 0.6722 - val_loss: 1.0663 - val_accuracy: 0.6115
# Epoch 48/100
# 897/897 [==============================] - 29s 33ms/step - loss: 0.8648 - accuracy: 0.6788 - val_loss: 1.0598 - val_accuracy: 0.6225
# Epoch 49/100
# 897/897 [==============================] - 29s 32ms/step - loss: 0.8513 - accuracy: 0.6824 - val_loss: 1.0494 - val_accuracy: 0.6191
# Epoch 50/100
# 897/897 [==============================] - 29s 32ms/step - loss: 0.8366 - accuracy: 0.6890 - val_loss: 1.0650 - val_accuracy: 0.6204
# Epoch 51/100
# 897/897 [==============================] - 29s 32ms/step - loss: 0.8213 - accuracy: 0.6948 - val_loss: 1.0605 - val_accuracy: 0.6164
# Epoch 52/100
# 897/897 [==============================] - 30s 33ms/step - loss: 0.8083 - accuracy: 0.7015 - val_loss: 1.0608 - val_accuracy: 0.6237
# Epoch 53/100
# 897/897 [==============================] - 30s 33ms/step - loss: 0.7896 - accuracy: 0.7075 - val_loss: 1.0705 - val_accuracy: 0.6230
# Epoch 54/100
# 897/897 [==============================] - 34s 38ms/step - loss: 0.7789 - accuracy: 0.7104 - val_loss: 1.0640 - val_accuracy: 0.6208
# Epoch 55/100
# 897/897 [==============================] - 35s 39ms/step - loss: 0.7640 - accuracy: 0.7174 - val_loss: 1.0797 - val_accuracy: 0.6247
# Epoch 56/100
# 897/897 [==============================] - 34s 37ms/step - loss: 0.7529 - accuracy: 0.7202 - val_loss: 1.0932 - val_accuracy: 0.6223
# Epoch 57/100
# 897/897 [==============================] - 33s 37ms/step - loss: 0.7363 - accuracy: 0.7315 - val_loss: 1.0797 - val_accuracy: 0.6225
# Epoch 58/100
# 897/897 [==============================] - 31s 34ms/step - loss: 0.7150 - accuracy: 0.7356 - val_loss: 1.0943 - val_accuracy: 0.6261
# Epoch 59/100
# 897/897 [==============================] - 30s 34ms/step - loss: 0.7015 - accuracy: 0.7376 - val_loss: 1.1164 - val_accuracy: 0.6215
# Epoch 60/100
# 897/897 [==============================] - 30s 33ms/step - loss: 0.6899 - accuracy: 0.7432 - val_loss: 1.0890 - val_accuracy: 0.6290
# Epoch 61/100
# 897/897 [==============================] - 31s 35ms/step - loss: 0.6690 - accuracy: 0.7532 - val_loss: 1.1428 - val_accuracy: 0.6211
# Epoch 62/100
# 897/897 [==============================] - 32s 36ms/step - loss: 0.6578 - accuracy: 0.7579 - val_loss: 1.1201 - val_accuracy: 0.6283
# Epoch 63/100
# 897/897 [==============================] - 31s 35ms/step - loss: 0.6468 - accuracy: 0.7622 - val_loss: 1.1043 - val_accuracy: 0.6295
# Epoch 64/100
# 897/897 [==============================] - 31s 34ms/step - loss: 0.6213 - accuracy: 0.7734 - val_loss: 1.1270 - val_accuracy: 0.6249
# Epoch 65/100
# 897/897 [==============================] - 31s 35ms/step - loss: 0.6174 - accuracy: 0.7733 - val_loss: 1.1614 - val_accuracy: 0.6283
# Epoch 66/100
# 897/897 [==============================] - 30s 33ms/step - loss: 0.5988 - accuracy: 0.7798 - val_loss: 1.1506 - val_accuracy: 0.6267
# Epoch 67/100
# 897/897 [==============================] - 31s 34ms/step - loss: 0.5925 - accuracy: 0.7849 - val_loss: 1.1504 - val_accuracy: 0.6253
# Epoch 68/100
# 897/897 [==============================] - 30s 33ms/step - loss: 0.5723 - accuracy: 0.7913 - val_loss: 1.1425 - val_accuracy: 0.6355
# Epoch 69/100
# 897/897 [==============================] - 30s 34ms/step - loss: 0.5642 - accuracy: 0.7938 - val_loss: 1.1565 - val_accuracy: 0.6303
# Epoch 70/100
# 897/897 [==============================] - 34s 38ms/step - loss: 0.5470 - accuracy: 0.8012 - val_loss: 1.1836 - val_accuracy: 0.6324
# Epoch 71/100
# 897/897 [==============================] - 35s 39ms/step - loss: 0.5304 - accuracy: 0.8078 - val_loss: 1.2063 - val_accuracy: 0.6349
# Epoch 72/100
# 897/897 [==============================] - 35s 39ms/step - loss: 0.5191 - accuracy: 0.8141 - val_loss: 1.1538 - val_accuracy: 0.6370
# Epoch 73/100
# 897/897 [==============================] - 35s 39ms/step - loss: 0.5023 - accuracy: 0.8195 - val_loss: 1.1855 - val_accuracy: 0.6449
# Epoch 74/100
# 897/897 [==============================] - 34s 37ms/step - loss: 0.4981 - accuracy: 0.8186 - val_loss: 1.2115 - val_accuracy: 0.6343
# Epoch 75/100
# 897/897 [==============================] - 30s 34ms/step - loss: 0.4864 - accuracy: 0.8249 - val_loss: 1.1981 - val_accuracy: 0.6424
# Epoch 76/100
# 897/897 [==============================] - 30s 33ms/step - loss: 0.4706 - accuracy: 0.8305 - val_loss: 1.2001 - val_accuracy: 0.6462
# Epoch 77/100
# 897/897 [==============================] - 30s 34ms/step - loss: 0.4519 - accuracy: 0.8357 - val_loss: 1.2749 - val_accuracy: 0.6345
# Epoch 78/100
# 897/897 [==============================] - 30s 34ms/step - loss: 0.4504 - accuracy: 0.8402 - val_loss: 1.2107 - val_accuracy: 0.6486
# Epoch 79/100
# 897/897 [==============================] - 30s 34ms/step - loss: 0.4426 - accuracy: 0.8411 - val_loss: 1.2495 - val_accuracy: 0.6288
# Epoch 80/100
# 897/897 [==============================] - 34s 38ms/step - loss: 0.4230 - accuracy: 0.8474 - val_loss: 1.2741 - val_accuracy: 0.6369
# Epoch 81/100
# 897/897 [==============================] - 33s 36ms/step - loss: 0.4236 - accuracy: 0.8467 - val_loss: 1.2551 - val_accuracy: 0.6401
# Epoch 82/100
# 897/897 [==============================] - 33s 37ms/step - loss: 0.4114 - accuracy: 0.8508 - val_loss: 1.2496 - val_accuracy: 0.6436
# Epoch 83/100
# 897/897 [==============================] - 33s 36ms/step - loss: 0.3952 - accuracy: 0.8587 - val_loss: 1.2441 - val_accuracy: 0.6451
# Epoch 84/100
# 897/897 [==============================] - 33s 37ms/step - loss: 0.3863 - accuracy: 0.8630 - val_loss: 1.3170 - val_accuracy: 0.6459
# Epoch 85/100
# 897/897 [==============================] - 33s 37ms/step - loss: 0.3692 - accuracy: 0.8684 - val_loss: 1.3303 - val_accuracy: 0.6366
# Epoch 86/100
# 897/897 [==============================] - 33s 36ms/step - loss: 0.3664 - accuracy: 0.8688 - val_loss: 1.2822 - val_accuracy: 0.6470
# Epoch 87/100
# 897/897 [==============================] - 33s 36ms/step - loss: 0.3591 - accuracy: 0.8719 - val_loss: 1.3288 - val_accuracy: 0.6396
# Epoch 88/100
# 897/897 [==============================] - 34s 37ms/step - loss: 0.3522 - accuracy: 0.8754 - val_loss: 1.3167 - val_accuracy: 0.6415
# Epoch 89/100
# 897/897 [==============================] - 33s 36ms/step - loss: 0.3500 - accuracy: 0.8757 - val_loss: 1.3130 - val_accuracy: 0.6392
# Epoch 90/100
# 897/897 [==============================] - 34s 37ms/step - loss: 0.3309 - accuracy: 0.8821 - val_loss: 1.3686 - val_accuracy: 0.6410
# Epoch 91/100
# 897/897 [==============================] - 35s 38ms/step - loss: 0.3267 - accuracy: 0.8845 - val_loss: 1.3849 - val_accuracy: 0.6431
# Epoch 92/100
# 897/897 [==============================] - 33s 37ms/step - loss: 0.3157 - accuracy: 0.8874 - val_loss: 1.3686 - val_accuracy: 0.6447
# Epoch 93/100
# 897/897 [==============================] - 33s 37ms/step - loss: 0.3106 - accuracy: 0.8903 - val_loss: 1.3843 - val_accuracy: 0.6459
# Epoch 94/100
# 897/897 [==============================] - 34s 37ms/step - loss: 0.3164 - accuracy: 0.8895 - val_loss: 1.3143 - val_accuracy: 0.6518
# Epoch 95/100
# 897/897 [==============================] - 33s 37ms/step - loss: 0.3017 - accuracy: 0.8947 - val_loss: 1.3957 - val_accuracy: 0.6447
# Epoch 96/100
# 897/897 [==============================] - 35s 38ms/step - loss: 0.2898 - accuracy: 0.8977 - val_loss: 1.3746 - val_accuracy: 0.6387
# Epoch 97/100
# 897/897 [==============================] - 32s 36ms/step - loss: 0.2827 - accuracy: 0.9012 - val_loss: 1.4116 - val_accuracy: 0.6483
# Epoch 98/100
# 897/897 [==============================] - 34s 38ms/step - loss: 0.2794 - accuracy: 0.9033 - val_loss: 1.4395 - val_accuracy: 0.6476
# Epoch 99/100
# 897/897 [==============================] - 33s 37ms/step - loss: 0.2670 - accuracy: 0.9058 - val_loss: 1.4353 - val_accuracy: 0.6482
# Epoch 100/100
# 897/897 [==============================] - 33s 37ms/step - loss: 0.2696 - accuracy: 0.9059 - val_loss: 1.4104 - val_accuracy: 0.6493

# %% [markdown]
# #Save model

# %%
model.save_weights('VGGNetcus_weights_100iters.h5')

# %% [markdown]
# # Predict model

# %%
import numpy as np
from keras.preprocessing import image
label_dict = {0:'Angry',1:'Disgust',2:'Fear',3:'Happy',4:'Neutral',5:'Sad',6:'Surprise'}

def predict(img_dir):
  img = load_img(img_dir,target_size = (48,48),color_mode = "rgb")
  img = np.array(img)
  img = np.expand_dims(img,axis = 0) # Makes image shape (1,48,48)
  img = img.reshape(1,48,48,3)
  result = model.predict(img)
  result = list(result[0])
  img_index = result.index(max(result))
  return label_dict[img_index]

result = predict("1.png")
print(result)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# Happy

# %% [markdown]
# # **Model evaluation:**

# %%
# Using Tensorboard 
# %tensorboard --logdir logs/fit

# %%
# Or using plotting 
# Create plots for accuracy and loss.
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
fig.set_size_inches(12,4)

ax[0].plot(history.history['accuracy'])
ax[0].plot(history.history['val_accuracy'])
ax[0].set_title('Training Accuracy vs Validation Accuracy')
ax[0].set_ylabel('Accuracy')
ax[0].set_xlabel('Epoch')
ax[0].legend(['Train', 'Validation'], loc='upper left')

ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[1].set_title('Training Loss vs Validation Loss')
ax[1].set_ylabel('Loss')
ax[1].set_xlabel('Epoch')
ax[1].legend(['Train', 'Validation'], loc='upper left')

plt.show()

# %%
# Create confusion matrix of our predictions

# compute predictions
predictions = model.predict_generator(generator=val_set)
y_pred = [np.argmax(probas) for probas in predictions]
y_test = val_set.classes
class_names = val_set.class_indices.keys()

# Create function to plot confussion matrix.
def plot_confusion_matrix(cm, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    plt.figure(figsize=(12,6), dpi=120)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')# **Live Class Monitoring System(Face Emotion Recognition)**
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.show()
    
# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, title='Normalized confusion matrix')
plt.show()

# %% [markdown]
# ## Pretrain Model

# %% [markdown]
# Load model:

# %% [markdown]
# loaded_model = load_model("AlexNet_model-100iters.h5")
# loaded_model.load_weights("AlexNet_model_weights-100iters.h5")
