# %% [markdown]
# <a href="https://colab.research.google.com/github/anishjohnson/Face-Emotion-Recognition/blob/main/FER/Colab%20Notebook/Face_Emotion_Recognition_Anish_Johnson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Face Emotion Recognition**

# %% [markdown]
# # **Objective**
# Our objective is to solve the above mentioned challenge by applying deep learning algorithms to live video data inorder to recognize the facial emotions and categorize them accordingly.

# %% [markdown]
# # **Dataset used**
# We have utilized the [FER 2013](https://www.kaggle.com/datasets/msambare/fer2013) dataset provided on Kaggle.<br>
# The data consists of 48x48 pixel grayscale images of faces. The faces have been automatically registered so that the face is more or less centred and occupies about the same amount of space in each image.<br>
#
# The task is to categorize each face based on the emotion shown in the facial expression into one of seven categories (0=Angry, 1=Disgust, 2=Fear, 3=Happy, 4=Sad, 5=Surprise, 6=Neutral). The training set consists of 28,709 examples and the public test set consists of 3,589 examples.

# %%
# !nvidia-smi
# !nvcc -V
# Out:
# Fri Feb 17 21:52:57 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 528.33       Driver Version: 528.33       CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   45C    P0    23W /  80W |      0MiB /  6144MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Fri_Jan__6_19:04:39_Pacific_Standard_Time_2023
# Cuda compilation tools, release 12.0, V12.0.140
# Build cuda_12.0.r12.0/compiler.32267302_0

# %% [markdown]
# ### **Let's Begin:**

# %% [markdown]
# # **Data Exploration:**

# %% [markdown]
# **Lets start by importing the required libraries.**

# %%
# Basic python libraries.
import datetime
import numpy as np
import os
import tensorflow
import tensorflow as tf
import matplotlib.pyplot as plt
from tqdm import tqdm
from PIL import Image
import itertools

# Get rid of warnings!
import warnings
warnings.filterwarnings('ignore')

# Deep learning libraries.
from sklearn.metrics import confusion_matrix
from tensorflow.keras import Model
from tensorflow.keras.models import load_model
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout
from keras.optimizers import SGD

print('Above libraries have been imported.')
# Out:
# Above libraries have been imported.

# %% [markdown]
# **Seperate the Training and Validation Data.**

# %%
tf.__version__

# %%
# Define the train and validataion data paths.
train_dir = 'Dataset/train'
val_dir = 'Dataset/test'

# %%
# Define the default image size.
img_size = 48

# Define the seven emotions provided in dataset.
emotion_list = ['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral']

# Plot the images with each distinct emotions.
plt.figure(figsize=(18,22))
i = 1
for expression in emotion_list:
    img = load_img((train_dir + '/' + expression +'/'+ os.listdir(train_dir + '/' + expression)[59]))
    plt.subplot(1,7,i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()

# %% [markdown]
# **Have a look at our data.**

# %% [markdown]
# **Perform some Data Augmentation on train and validations sets.**

# %% [markdown]
# # **Data Preprocessing:**

# %%
# Rescale the data.
'''
Before we proceed we need to rescale our data by multiplying it to 1/255.
This is done so we get target values between 0 and 1.
'''
# Rescale train data.
datagen_train = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

# Rescale validation data.
datagen_val = ImageDataGenerator(rescale = 1./255,
                                 )

print('Above data generator functions have been created.')
# Out:
# Above data generator functions have been created.

# %%
# Perform data augmentation.
'''
Data augmentation is a technique to artificially create new training data from existing training data. 
It helps us to increase the size of the dataset and introduce variability in the dataset.
'''
# Define the default image size.
img_size = 48

# Define batch size.
batch_size = 64

                                         
# Train data
train_set = datagen_train.flow_from_directory(
    directory=train_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)

# Validation data
val_set = datagen_train.flow_from_directory(
    directory=val_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)


print('Train and Validation sets have been created.')
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.
# Train and Validation sets have been created.

# %% [markdown]
# **Now lets create our custom CNN model.**

# %% [markdown]
# # **Build CNN Model:**

# %% [markdown]
# **Before we start building the neural network lets understand some of the terms that we will be using.**
#
# * **Model = sequential** : A Sequential model is appropriate for a plain stack of layers where each layer has exactly one input tensor and one output tensor.
#
# * **Padding** = The padding parameter of the Keras Conv2D class can take one of two values: 'valid' or 'same'. Setting the value to “valid” parameter means that the input volume is not zero-padded and the spatial dimensions are allowed to reduce via the natural application of convolution.
#
# * **Activation** = relu :The rectified linear activation function or ReLU for short is a piecewise linear function that will output the input directly if it is positive, otherwise, it will output zero. It has become the default activation function for many types of neural networks because a model that uses it is easier to train and often achieves better performance.
#
# * **Maxpooling** = Maximum pooling, or max pooling, is a pooling operation that calculates the maximum, or largest, value in each patch of each feature map. The results are down sampled or pooled feature maps that highlight the most present feature in the patch, not the average presence of the feature in the case of average pooling.
#
# * **Batch normalization** = Batch normalization is a technique for training very deep neural networks that standardizes the inputs to a layer for each mini-batch. This has the effect of stabilizing the learning process and dramatically reducing the number of training epochs required to train deep networks.
#
# * **Dropout** = Dropout is a technique used to prevent a model from overfitting. Dropout works by randomly setting the outgoing edges of hidden units (neurons that make up hidden layers) to 0 at each update of the training phase.
#
# * **Adam** = Adaptive Moment Estimation is an algorithm for optimization technique for gradient descent. The method is really efficient when working with large problem involving a lot of data or parameters. It requires less memory and is efficient. Intuitively, it is a combination of the ‘gradient descent with momentum’ algorithm and the ‘RMSP’ algorithm. It uses the squared gradients to scale the learning rate like RMSprop and it takes advantage of momentum by using moving average of the gradient instead of gradient itself like SGD with momentum.

# %%
class VGGNet(Sequential):
  def __init__(self, input_shape, num_classes):
    super().__init__()

    self.add(Conv2D(64, (3, 3), activation='relu', padding='same', input_shape=(48, 48, 3)))
    self.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
    self.add(MaxPooling2D(pool_size=(2, 2)))

    self.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
    self.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
    self.add(MaxPooling2D(pool_size=(2, 2)))

    self.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
    self.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
    self.add(MaxPooling2D(pool_size=(2, 2)))

    self.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
    self.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
    self.add(MaxPooling2D(pool_size=(2, 2)))

    self.add(Flatten())
    self.add(Dense(4096, activation='relu'))
    self.add(Dense(4096, activation='relu'))
    self.add(Dense(4096, activation='relu'))
    self.add(Dense(4096, activation='relu'))
    self.add(Dense(1000, activation='relu'))
    self.add(Dense(1000, activation='relu'))
    self.add(Dense(num_classes, activation='softmax'))
    opt = SGD(lr=0.011)
    self.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# %%
model = VGGNet((48,48,3),7)

epochs = 80
steps_per_epoch = train_set.n//train_set.batch_size
validation_steps = val_set.n//val_set.batch_size

history = model.fit(train_set,
                              steps_per_epoch=steps_per_epoch,
                              epochs=epochs,
                              batch_size = 32,
                              validation_data=val_set,
                              validation_steps=validation_steps)
# Out:
# Epoch 1/80
# 448/448 [==============================] - 189s 406ms/step - loss: 1.8552 - accuracy: 0.2509 - val_loss: 1.8153 - val_accuracy: 0.2475
# Epoch 2/80
# 448/448 [==============================] - 27s 59ms/step - loss: 1.8089 - accuracy: 0.2514 - val_loss: 1.8097 - val_accuracy: 0.2475
# Epoch 3/80
# 448/448 [==============================] - 27s 60ms/step - loss: 1.8035 - accuracy: 0.2511 - val_loss: 1.8023 - val_accuracy: 0.2475
# Epoch 4/80
# 448/448 [==============================] - 27s 59ms/step - loss: 1.7942 - accuracy: 0.2523 - val_loss: 1.7876 - val_accuracy: 0.2478
# Epoch 5/80
# 448/448 [==============================] - 27s 59ms/step - loss: 1.7802 - accuracy: 0.2578 - val_loss: 1.7658 - val_accuracy: 0.2801
# Epoch 6/80
# 448/448 [==============================] - 27s 60ms/step - loss: 1.7579 - accuracy: 0.2817 - val_loss: 1.7524 - val_accuracy: 0.2987
# Epoch 7/80
# 448/448 [==============================] - 27s 60ms/step - loss: 1.7295 - accuracy: 0.3051 - val_loss: 1.7200 - val_accuracy: 0.3186
# Epoch 8/80
# 448/448 [==============================] - 29s 65ms/step - loss: 1.7039 - accuracy: 0.3221 - val_loss: 1.6740 - val_accuracy: 0.3450
# Epoch 9/80
# 448/448 [==============================] - 33s 74ms/step - loss: 1.6759 - accuracy: 0.3368 - val_loss: 1.6502 - val_accuracy: 0.3544
# Epoch 10/80
# 448/448 [==============================] - 33s 74ms/step - loss: 1.6514 - accuracy: 0.3488 - val_loss: 1.6613 - val_accuracy: 0.3535
# Epoch 11/80
# 448/448 [==============================] - 33s 73ms/step - loss: 1.6272 - accuracy: 0.3586 - val_loss: 1.6238 - val_accuracy: 0.3743
# Epoch 12/80
# 448/448 [==============================] - 28s 62ms/step - loss: 1.6051 - accuracy: 0.3709 - val_loss: 1.5866 - val_accuracy: 0.3906
# Epoch 13/80
# 448/448 [==============================] - 28s 63ms/step - loss: 1.5798 - accuracy: 0.3849 - val_loss: 1.5541 - val_accuracy: 0.4005
# Epoch 14/80
# 448/448 [==============================] - 28s 62ms/step - loss: 1.5578 - accuracy: 0.3954 - val_loss: 1.5370 - val_accuracy: 0.4064
# Epoch 15/80
# 448/448 [==============================] - 28s 63ms/step - loss: 1.5364 - accuracy: 0.4050 - val_loss: 1.5191 - val_accuracy: 0.4136
# Epoch 16/80
# 448/448 [==============================] - 29s 64ms/step - loss: 1.5131 - accuracy: 0.4123 - val_loss: 1.5041 - val_accuracy: 0.4258
# Epoch 17/80
# 448/448 [==============================] - 28s 63ms/step - loss: 1.4933 - accuracy: 0.4248 - val_loss: 1.4807 - val_accuracy: 0.4308
# Epoch 18/80
# 448/448 [==============================] - 29s 64ms/step - loss: 1.4726 - accuracy: 0.4367 - val_loss: 1.4877 - val_accuracy: 0.4216
# Epoch 19/80
# 448/448 [==============================] - 29s 64ms/step - loss: 1.4516 - accuracy: 0.4412 - val_loss: 1.4947 - val_accuracy: 0.4233
# Epoch 20/80
# 448/448 [==============================] - 31s 69ms/step - loss: 1.4365 - accuracy: 0.4499 - val_loss: 1.4880 - val_accuracy: 0.4252
# Epoch 21/80
# 448/448 [==============================] - 29s 65ms/step - loss: 1.4118 - accuracy: 0.4577 - val_loss: 1.4848 - val_accuracy: 0.4315
# Epoch 22/80
# 448/448 [==============================] - 29s 64ms/step - loss: 1.3942 - accuracy: 0.4652 - val_loss: 1.4117 - val_accuracy: 0.4537
# Epoch 23/80
# 448/448 [==============================] - 29s 64ms/step - loss: 1.3733 - accuracy: 0.4746 - val_loss: 1.4378 - val_accuracy: 0.4392
# Epoch 24/80
# 448/448 [==============================] - 29s 65ms/step - loss: 1.3551 - accuracy: 0.4837 - val_loss: 1.3724 - val_accuracy: 0.4803
# Epoch 25/80
# 448/448 [==============================] - 29s 64ms/step - loss: 1.3350 - accuracy: 0.4903 - val_loss: 1.3824 - val_accuracy: 0.4736
# Epoch 26/80
# 448/448 [==============================] - 29s 64ms/step - loss: 1.3197 - accuracy: 0.4959 - val_loss: 1.3815 - val_accuracy: 0.4767
# Epoch 27/80
# 448/448 [==============================] - 28s 63ms/step - loss: 1.2971 - accuracy: 0.5070 - val_loss: 1.4125 - val_accuracy: 0.4584
# Epoch 28/80
# 448/448 [==============================] - 29s 64ms/step - loss: 1.2796 - accuracy: 0.5135 - val_loss: 1.3711 - val_accuracy: 0.4760
# Epoch 29/80
# 448/448 [==============================] - 31s 68ms/step - loss: 1.2570 - accuracy: 0.5245 - val_loss: 1.3747 - val_accuracy: 0.4865
# Epoch 30/80
# 448/448 [==============================] - 33s 73ms/step - loss: 1.2389 - accuracy: 0.5311 - val_loss: 1.3813 - val_accuracy: 0.4630
# Epoch 31/80
# 448/448 [==============================] - 32s 72ms/step - loss: 1.2185 - accuracy: 0.5363 - val_loss: 1.3504 - val_accuracy: 0.4881
# Epoch 32/80
# 448/448 [==============================] - 32s 72ms/step - loss: 1.1987 - accuracy: 0.5469 - val_loss: 1.3596 - val_accuracy: 0.4789
# Epoch 33/80
# 448/448 [==============================] - 32s 72ms/step - loss: 1.1741 - accuracy: 0.5599 - val_loss: 1.3516 - val_accuracy: 0.4989
# Epoch 34/80
# 448/448 [==============================] - 32s 71ms/step - loss: 1.1590 - accuracy: 0.5659 - val_loss: 1.3179 - val_accuracy: 0.5040
# Epoch 35/80
# 448/448 [==============================] - 32s 72ms/step - loss: 1.1362 - accuracy: 0.5733 - val_loss: 1.3111 - val_accuracy: 0.5109
# Epoch 36/80
# 448/448 [==============================] - 33s 73ms/step - loss: 1.1104 - accuracy: 0.5841 - val_loss: 1.3404 - val_accuracy: 0.4961
# Epoch 37/80
# 448/448 [==============================] - 33s 73ms/step - loss: 1.0900 - accuracy: 0.5911 - val_loss: 1.3077 - val_accuracy: 0.5007
# Epoch 38/80
# 448/448 [==============================] - 33s 74ms/step - loss: 1.0680 - accuracy: 0.5973 - val_loss: 1.3057 - val_accuracy: 0.5160
# Epoch 39/80
# 448/448 [==============================] - 33s 73ms/step - loss: 1.0442 - accuracy: 0.6126 - val_loss: 1.2896 - val_accuracy: 0.5177
# Epoch 40/80
# 448/448 [==============================] - 33s 72ms/step - loss: 1.0156 - accuracy: 0.6218 - val_loss: 1.3625 - val_accuracy: 0.5022
# Epoch 41/80
# 448/448 [==============================] - 33s 73ms/step - loss: 0.9918 - accuracy: 0.6335 - val_loss: 1.3281 - val_accuracy: 0.5177
# Epoch 42/80
# 448/448 [==============================] - 32s 71ms/step - loss: 0.9694 - accuracy: 0.6402 - val_loss: 1.3146 - val_accuracy: 0.5283
# Epoch 43/80
# 448/448 [==============================] - 32s 71ms/step - loss: 0.9399 - accuracy: 0.6522 - val_loss: 1.3206 - val_accuracy: 0.5223
# Epoch 44/80
# 448/448 [==============================] - 32s 70ms/step - loss: 0.9107 - accuracy: 0.6654 - val_loss: 1.3671 - val_accuracy: 0.5172
# Epoch 45/80
# 448/448 [==============================] - 32s 71ms/step - loss: 0.8867 - accuracy: 0.6727 - val_loss: 1.3649 - val_accuracy: 0.5366
# Epoch 46/80
# 448/448 [==============================] - 33s 72ms/step - loss: 0.8592 - accuracy: 0.6822 - val_loss: 1.3036 - val_accuracy: 0.5335
# Epoch 47/80
# 448/448 [==============================] - 32s 72ms/step - loss: 0.8296 - accuracy: 0.6953 - val_loss: 1.4060 - val_accuracy: 0.5220
# Epoch 48/80
# 448/448 [==============================] - 32s 71ms/step - loss: 0.8041 - accuracy: 0.7050 - val_loss: 1.4327 - val_accuracy: 0.5285
# Epoch 49/80
# 448/448 [==============================] - 32s 71ms/step - loss: 0.7807 - accuracy: 0.7136 - val_loss: 1.3971 - val_accuracy: 0.5272
# Epoch 50/80
# 448/448 [==============================] - 31s 70ms/step - loss: 0.7523 - accuracy: 0.7280 - val_loss: 1.4500 - val_accuracy: 0.5384
# Epoch 51/80
# 448/448 [==============================] - 31s 70ms/step - loss: 0.7235 - accuracy: 0.7385 - val_loss: 1.6186 - val_accuracy: 0.5075
# Epoch 52/80
# 448/448 [==============================] - 32s 71ms/step - loss: 0.6936 - accuracy: 0.7466 - val_loss: 1.4710 - val_accuracy: 0.5405
# Epoch 53/80
# 448/448 [==============================] - 31s 70ms/step - loss: 0.6707 - accuracy: 0.7565 - val_loss: 1.4408 - val_accuracy: 0.5258
# Epoch 54/80
# 448/448 [==============================] - 31s 70ms/step - loss: 0.6459 - accuracy: 0.7680 - val_loss: 1.4810 - val_accuracy: 0.5453
# Epoch 55/80
# 448/448 [==============================] - 31s 70ms/step - loss: 0.6192 - accuracy: 0.7751 - val_loss: 1.4414 - val_accuracy: 0.5377
# Epoch 56/80
# 448/448 [==============================] - 32s 70ms/step - loss: 0.5958 - accuracy: 0.7860 - val_loss: 1.6158 - val_accuracy: 0.5195
# Epoch 57/80
# 448/448 [==============================] - 32s 70ms/step - loss: 0.5691 - accuracy: 0.7966 - val_loss: 1.5782 - val_accuracy: 0.5378
# Epoch 58/80
# 448/448 [==============================] - 29s 65ms/step - loss: 0.5502 - accuracy: 0.8045 - val_loss: 1.5755 - val_accuracy: 0.5414
# Epoch 59/80
# 448/448 [==============================] - 30s 67ms/step - loss: 0.5301 - accuracy: 0.8121 - val_loss: 1.5821 - val_accuracy: 0.5205
# Epoch 60/80
# 448/448 [==============================] - 30s 67ms/step - loss: 0.5030 - accuracy: 0.8220 - val_loss: 1.7978 - val_accuracy: 0.5191
# Epoch 61/80
# 448/448 [==============================] - 30s 67ms/step - loss: 0.4789 - accuracy: 0.8302 - val_loss: 1.6479 - val_accuracy: 0.5462
# Epoch 62/80
# 448/448 [==============================] - 30s 68ms/step - loss: 0.4712 - accuracy: 0.8353 - val_loss: 1.6102 - val_accuracy: 0.5484
# Epoch 63/80
# 448/448 [==============================] - 30s 67ms/step - loss: 0.4467 - accuracy: 0.8445 - val_loss: 1.7557 - val_accuracy: 0.5554
# Epoch 64/80
# 448/448 [==============================] - 30s 67ms/step - loss: 0.4277 - accuracy: 0.8507 - val_loss: 1.7244 - val_accuracy: 0.5400
# Epoch 65/80
# 448/448 [==============================] - 30s 67ms/step - loss: 0.4067 - accuracy: 0.8566 - val_loss: 1.7772 - val_accuracy: 0.5241
# Epoch 66/80
# 448/448 [==============================] - 30s 67ms/step - loss: 0.3866 - accuracy: 0.8646 - val_loss: 1.7747 - val_accuracy: 0.5505
# Epoch 67/80
# 448/448 [==============================] - 30s 67ms/step - loss: 0.3790 - accuracy: 0.8668 - val_loss: 1.6831 - val_accuracy: 0.5494
# Epoch 68/80
# 448/448 [==============================] - 31s 69ms/step - loss: 0.3615 - accuracy: 0.8741 - val_loss: 1.7399 - val_accuracy: 0.5419
# Epoch 69/80
# 448/448 [==============================] - 29s 65ms/step - loss: 0.3378 - accuracy: 0.8826 - val_loss: 1.8043 - val_accuracy: 0.5527
# Epoch 70/80
# 448/448 [==============================] - 29s 64ms/step - loss: 0.3207 - accuracy: 0.8879 - val_loss: 2.0564 - val_accuracy: 0.5290
# Epoch 71/80
# 448/448 [==============================] - 29s 64ms/step - loss: 0.3130 - accuracy: 0.8899 - val_loss: 1.9390 - val_accuracy: 0.5441
# Epoch 72/80
# 448/448 [==============================] - 29s 64ms/step - loss: 0.3084 - accuracy: 0.8926 - val_loss: 1.7526 - val_accuracy: 0.5444
# Epoch 73/80
# 448/448 [==============================] - 29s 65ms/step - loss: 0.2862 - accuracy: 0.9008 - val_loss: 1.8403 - val_accuracy: 0.5495
# Epoch 74/80
# 448/448 [==============================] - 29s 64ms/step - loss: 0.2735 - accuracy: 0.9048 - val_loss: 2.2161 - val_accuracy: 0.5439
# Epoch 75/80
# 448/448 [==============================] - 29s 65ms/step - loss: 0.2725 - accuracy: 0.9076 - val_loss: 1.9896 - val_accuracy: 0.5410
# Epoch 76/80
# 448/448 [==============================] - 29s 64ms/step - loss: 0.2611 - accuracy: 0.9110 - val_loss: 1.8801 - val_accuracy: 0.5603
# Epoch 77/80
# 448/448 [==============================] - 29s 65ms/step - loss: 0.2439 - accuracy: 0.9179 - val_loss: 2.1134 - val_accuracy: 0.5495
# Epoch 78/80
# 448/448 [==============================] - 29s 64ms/step - loss: 0.2339 - accuracy: 0.9207 - val_loss: 2.0435 - val_accuracy: 0.5438
# Epoch 79/80
# 448/448 [==============================] - 29s 65ms/step - loss: 0.2199 - accuracy: 0.9276 - val_loss: 2.0549 - val_accuracy: 0.5555
# Epoch 80/80
# 448/448 [==============================] - 29s 65ms/step - loss: 0.2203 - accuracy: 0.9249 - val_loss: 1.9597 - val_accuracy: 0.5435

# %% [markdown]
# #Save model

# %%
model.save_weights('VGGNet_weights_iters80.h5')

# %% [markdown]
# # Predict model

# %%
label_dict = {0:'Angry',1:'Disgust',2:'Fear',3:'Happy',4:'Neutral',5:'Sad',6:'Surprise'}

def predict(img_dir):
  img = load_img(img_dir,target_size = (48,48),color_mode = "rgb")
  img = np.array(img)
  img = np.expand_dims(img,axis = 0) # Makes image shape (1,48,48)
  img = img.reshape(1,48,48,3)
  result = model.predict(img)
  result = list(result[0])
  img_index = result.index(max(result))
  return label_dict[img_index]

result = predict("/content/test/happy/PrivateTest_10513598.jpg")
print(result)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 13
#      10   img_index = result.index(max(result))
#      11   return label_dict[img_index]
# ---> 13 result = predict("/content/test/happy/PrivateTest_10513598.jpg")
#      14 print(result)
#
# Cell In[13], line 4, in predict(img_dir)
#       3 def predict(img_dir):
# ----> 4   img = load_img(img_dir,target_size = (48,48),color_mode = "rgb")
#       5   img = np.array(img)
#       6   img = np.expand_dims(img,axis = 0) # Makes image shape (1,48,48)
#
# File d:\venv-python\lib\site-packages\keras\utils\image_utils.py:422, in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420     if isinstance(path, pathlib.Path):
#     421         path = str(path.resolve())
# --> 422     with open(path, "rb") as f:
#     423         img = pil_image.open(io.BytesIO(f.read()))
#     424 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/test/happy/PrivateTest_10513598.jpg'

# %% [markdown]
# # **Model evaluation:**

# %%
# Using Tensorboard 
# %tensorboard --logdir logs/fit
# Out:
# UsageError: Line magic function `%tensorboard` not found.

# %%
# Or using plotting 
# Create plots for accuracy and loss.
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
fig.set_size_inches(12,4)

ax[0].plot(history.history['accuracy'])
ax[0].plot(history.history['val_accuracy'])
ax[0].set_title('Training Accuracy vs Validation Accuracy')
ax[0].set_ylabel('Accuracy')
ax[0].set_xlabel('Epoch')
ax[0].legend(['Train', 'Validation'], loc='upper left')

ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[1].set_title('Training Loss vs Validation Loss')
ax[1].set_ylabel('Loss')
ax[1].set_xlabel('Epoch')
ax[1].legend(['Train', 'Validation'], loc='upper left')

plt.show()

# %%
# Create confusion matrix of our predictions

# compute predictions
predictions = model.predict_generator(generator=val_set)
y_pred = [np.argmax(probas) for probas in predictions]
y_test = val_set.classes
class_names = val_set.class_indices.keys()

# Create function to plot confussion matrix.
def plot_confusion_matrix(cm, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    plt.figure(figsize=(12,6), dpi=120)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')# **Live Class Monitoring System(Face Emotion Recognition)**
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.show()
    
# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, title='Normalized confusion matrix')
plt.show()

# %% [markdown]
# ## Pretrain Model

# %% [markdown]
# Load model:

# %% [markdown]
# loaded_model = load_model("AlexNet_model-100iters.h5")
# loaded_model.load_weights("AlexNet_model_weights-100iters.h5")
